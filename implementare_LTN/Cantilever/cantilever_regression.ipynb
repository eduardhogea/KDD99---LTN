# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
#df.sample(5)
#df.shape
df = df.head(int(len(df)*(70/100)))
df.shape
# Out:
# (25601, 11)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (25601, 11)

# %%
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

batch_size= 128
ds_train = tf.data.Dataset.from_tensor_slices((x[:21000],y[:21000])).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x[21000:],y[21000:])).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-04-30 15:25:05.591933: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-30 15:25:05.592039: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[1],hidden_layer_sizes=(16,16))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.79321
# 2022-04-30 15:25:06.312139: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-30 15:25:06.312193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 300

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="regression_results.csv",
    track_metrics=1
)
# Out:
# 2022-04-30 15:25:06.494700: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 15:25:07.987510: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 15:25:08.141062: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 15:25:08.322403: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8629, test_sat: 0.8789, train_accuracy: 0.3493, test_accuracy: 0.2864
# Epoch 1, train_sat: 0.8815, test_sat: 0.8830, train_accuracy: 0.2794, test_accuracy: 0.2752
# Epoch 2, train_sat: 0.8857, test_sat: 0.8883, train_accuracy: 0.2682, test_accuracy: 0.2615
# Epoch 3, train_sat: 0.8915, test_sat: 0.8949, train_accuracy: 0.2535, test_accuracy: 0.2452
# Epoch 4, train_sat: 0.8975, test_sat: 0.8998, train_accuracy: 0.2388, test_accuracy: 0.2338
# Epoch 5, train_sat: 0.9009, test_sat: 0.9014, train_accuracy: 0.2314, test_accuracy: 0.2309
# Epoch 6, train_sat: 0.9019, test_sat: 0.9016, train_accuracy: 0.2298, test_accuracy: 0.2308
# Epoch 7, train_sat: 0.9021, test_sat: 0.9017, train_accuracy: 0.2297, test_accuracy: 0.2309
# Epoch 8, train_sat: 0.9021, test_sat: 0.9017, train_accuracy: 0.2297, test_accuracy: 0.2309
# Epoch 9, train_sat: 0.9022, test_sat: 0.9018, train_accuracy: 0.2296, test_accuracy: 0.2308
# Epoch 10, train_sat: 0.9022, test_sat: 0.9018, train_accuracy: 0.2296, test_accuracy: 0.2307
# Epoch 11, train_sat: 0.9022, test_sat: 0.9018, train_accuracy: 0.2295, test_accuracy: 0.2306
# Epoch 12, train_sat: 0.9022, test_sat: 0.9019, train_accuracy: 0.2294, test_accuracy: 0.2305
# Epoch 13, train_sat: 0.9023, test_sat: 0.9019, train_accuracy: 0.2294, test_accuracy: 0.2304
# Epoch 14, train_sat: 0.9023, test_sat: 0.9019, train_accuracy: 0.2293, test_accuracy: 0.2304
# Epoch 15, train_sat: 0.9023, test_sat: 0.9019, train_accuracy: 0.2292, test_accuracy: 0.2303
# Epoch 16, train_sat: 0.9023, test_sat: 0.9020, train_accuracy: 0.2291, test_accuracy: 0.2302
# Epoch 17, train_sat: 0.9024, test_sat: 0.9020, train_accuracy: 0.2291, test_accuracy: 0.2301
# Epoch 18, train_sat: 0.9024, test_sat: 0.9020, train_accuracy: 0.2290, test_accuracy: 0.2300
# Epoch 19, train_sat: 0.9024, test_sat: 0.9021, train_accuracy: 0.2289, test_accuracy: 0.2299
# Epoch 20, train_sat: 0.9025, test_sat: 0.9021, train_accuracy: 0.2288, test_accuracy: 0.2298
# Epoch 21, train_sat: 0.9025, test_sat: 0.9022, train_accuracy: 0.2286, test_accuracy: 0.2296
# Epoch 22, train_sat: 0.9026, test_sat: 0.9022, train_accuracy: 0.2285, test_accuracy: 0.2295
# Epoch 23, train_sat: 0.9026, test_sat: 0.9023, train_accuracy: 0.2284, test_accuracy: 0.2293
# Epoch 24, train_sat: 0.9027, test_sat: 0.9023, train_accuracy: 0.2282, test_accuracy: 0.2292
# Epoch 25, train_sat: 0.9027, test_sat: 0.9024, train_accuracy: 0.2281, test_accuracy: 0.2290
# Epoch 26, train_sat: 0.9028, test_sat: 0.9025, train_accuracy: 0.2279, test_accuracy: 0.2288
# Epoch 27, train_sat: 0.9028, test_sat: 0.9025, train_accuracy: 0.2278, test_accuracy: 0.2287
# Epoch 28, train_sat: 0.9029, test_sat: 0.9026, train_accuracy: 0.2276, test_accuracy: 0.2285
# Epoch 29, train_sat: 0.9030, test_sat: 0.9027, train_accuracy: 0.2274, test_accuracy: 0.2282
# Epoch 30, train_sat: 0.9030, test_sat: 0.9028, train_accuracy: 0.2272, test_accuracy: 0.2280
# Epoch 31, train_sat: 0.9031, test_sat: 0.9028, train_accuracy: 0.2270, test_accuracy: 0.2278
# Epoch 32, train_sat: 0.9032, test_sat: 0.9029, train_accuracy: 0.2268, test_accuracy: 0.2276
# Epoch 33, train_sat: 0.9033, test_sat: 0.9030, train_accuracy: 0.2266, test_accuracy: 0.2273
# Epoch 34, train_sat: 0.9034, test_sat: 0.9031, train_accuracy: 0.2263, test_accuracy: 0.2271
# Epoch 35, train_sat: 0.9034, test_sat: 0.9032, train_accuracy: 0.2261, test_accuracy: 0.2268
# Epoch 36, train_sat: 0.9035, test_sat: 0.9033, train_accuracy: 0.2258, test_accuracy: 0.2265
# Epoch 37, train_sat: 0.9036, test_sat: 0.9034, train_accuracy: 0.2255, test_accuracy: 0.2261
# Epoch 38, train_sat: 0.9038, test_sat: 0.9036, train_accuracy: 0.2252, test_accuracy: 0.2258
# Epoch 39, train_sat: 0.9039, test_sat: 0.9037, train_accuracy: 0.2248, test_accuracy: 0.2254
# Epoch 40, train_sat: 0.9040, test_sat: 0.9039, train_accuracy: 0.2244, test_accuracy: 0.2249
# Epoch 41, train_sat: 0.9042, test_sat: 0.9040, train_accuracy: 0.2240, test_accuracy: 0.2244
# Epoch 42, train_sat: 0.9043, test_sat: 0.9042, train_accuracy: 0.2235, test_accuracy: 0.2239
# Epoch 43, train_sat: 0.9045, test_sat: 0.9045, train_accuracy: 0.2230, test_accuracy: 0.2233
# Epoch 44, train_sat: 0.9047, test_sat: 0.9047, train_accuracy: 0.2224, test_accuracy: 0.2226
# Epoch 45, train_sat: 0.9050, test_sat: 0.9050, train_accuracy: 0.2218, test_accuracy: 0.2218
# Epoch 46, train_sat: 0.9052, test_sat: 0.9053, train_accuracy: 0.2210, test_accuracy: 0.2210
# Epoch 47, train_sat: 0.9055, test_sat: 0.9057, train_accuracy: 0.2202, test_accuracy: 0.2200
# Epoch 48, train_sat: 0.9059, test_sat: 0.9061, train_accuracy: 0.2192, test_accuracy: 0.2188
# Epoch 49, train_sat: 0.9063, test_sat: 0.9066, train_accuracy: 0.2181, test_accuracy: 0.2176
# Epoch 50, train_sat: 0.9068, test_sat: 0.9071, train_accuracy: 0.2169, test_accuracy: 0.2161
# Epoch 51, train_sat: 0.9073, test_sat: 0.9077, train_accuracy: 0.2155, test_accuracy: 0.2145
# Epoch 52, train_sat: 0.9079, test_sat: 0.9084, train_accuracy: 0.2139, test_accuracy: 0.2128
# Epoch 53, train_sat: 0.9085, test_sat: 0.9091, train_accuracy: 0.2122, test_accuracy: 0.2110
# Epoch 54, train_sat: 0.9092, test_sat: 0.9098, train_accuracy: 0.2105, test_accuracy: 0.2092
# Epoch 55, train_sat: 0.9099, test_sat: 0.9105, train_accuracy: 0.2088, test_accuracy: 0.2075
# Epoch 56, train_sat: 0.9105, test_sat: 0.9112, train_accuracy: 0.2073, test_accuracy: 0.2059
# Epoch 57, train_sat: 0.9112, test_sat: 0.9118, train_accuracy: 0.2059, test_accuracy: 0.2046
# Epoch 58, train_sat: 0.9117, test_sat: 0.9123, train_accuracy: 0.2047, test_accuracy: 0.2035
# Epoch 59, train_sat: 0.9121, test_sat: 0.9128, train_accuracy: 0.2037, test_accuracy: 0.2025
# Epoch 60, train_sat: 0.9125, test_sat: 0.9132, train_accuracy: 0.2029, test_accuracy: 0.2017
# Epoch 61, train_sat: 0.9129, test_sat: 0.9136, train_accuracy: 0.2021, test_accuracy: 0.2010
# Epoch 62, train_sat: 0.9132, test_sat: 0.9139, train_accuracy: 0.2015, test_accuracy: 0.2003
# Epoch 63, train_sat: 0.9134, test_sat: 0.9141, train_accuracy: 0.2009, test_accuracy: 0.1997
# Epoch 64, train_sat: 0.9137, test_sat: 0.9144, train_accuracy: 0.2004, test_accuracy: 0.1992
# Epoch 65, train_sat: 0.9139, test_sat: 0.9146, train_accuracy: 0.1999, test_accuracy: 0.1987
# Epoch 66, train_sat: 0.9141, test_sat: 0.9148, train_accuracy: 0.1995, test_accuracy: 0.1982
# Epoch 67, train_sat: 0.9143, test_sat: 0.9150, train_accuracy: 0.1991, test_accuracy: 0.1978
# Epoch 68, train_sat: 0.9144, test_sat: 0.9152, train_accuracy: 0.1987, test_accuracy: 0.1973
# Epoch 69, train_sat: 0.9146, test_sat: 0.9153, train_accuracy: 0.1983, test_accuracy: 0.1969
# Epoch 70, train_sat: 0.9147, test_sat: 0.9155, train_accuracy: 0.1979, test_accuracy: 0.1965
# Epoch 71, train_sat: 0.9149, test_sat: 0.9156, train_accuracy: 0.1975, test_accuracy: 0.1961
# Epoch 72, train_sat: 0.9150, test_sat: 0.9158, train_accuracy: 0.1972, test_accuracy: 0.1957
# Epoch 73, train_sat: 0.9151, test_sat: 0.9159, train_accuracy: 0.1968, test_accuracy: 0.1954
# Epoch 74, train_sat: 0.9153, test_sat: 0.9161, train_accuracy: 0.1965, test_accuracy: 0.1950
# Epoch 75, train_sat: 0.9154, test_sat: 0.9162, train_accuracy: 0.1961, test_accuracy: 0.1946
# Epoch 76, train_sat: 0.9155, test_sat: 0.9164, train_accuracy: 0.1958, test_accuracy: 0.1942
# Epoch 77, train_sat: 0.9157, test_sat: 0.9165, train_accuracy: 0.1955, test_accuracy: 0.1939
# Epoch 78, train_sat: 0.9158, test_sat: 0.9166, train_accuracy: 0.1951, test_accuracy: 0.1935
# Epoch 79, train_sat: 0.9159, test_sat: 0.9168, train_accuracy: 0.1948, test_accuracy: 0.1931
# Epoch 80, train_sat: 0.9161, test_sat: 0.9169, train_accuracy: 0.1944, test_accuracy: 0.1928
# Epoch 81, train_sat: 0.9162, test_sat: 0.9170, train_accuracy: 0.1941, test_accuracy: 0.1924
# Epoch 82, train_sat: 0.9163, test_sat: 0.9172, train_accuracy: 0.1937, test_accuracy: 0.1920
# Epoch 83, train_sat: 0.9165, test_sat: 0.9173, train_accuracy: 0.1933, test_accuracy: 0.1916
# Epoch 84, train_sat: 0.9166, test_sat: 0.9175, train_accuracy: 0.1929, test_accuracy: 0.1912
# Epoch 85, train_sat: 0.9168, test_sat: 0.9176, train_accuracy: 0.1925, test_accuracy: 0.1908
# Epoch 86, train_sat: 0.9169, test_sat: 0.9178, train_accuracy: 0.1921, test_accuracy: 0.1903
# Epoch 87, train_sat: 0.9171, test_sat: 0.9180, train_accuracy: 0.1917, test_accuracy: 0.1899
# Epoch 88, train_sat: 0.9172, test_sat: 0.9181, train_accuracy: 0.1913, test_accuracy: 0.1894
# Epoch 89, train_sat: 0.9174, test_sat: 0.9183, train_accuracy: 0.1908, test_accuracy: 0.1889
# Epoch 90, train_sat: 0.9176, test_sat: 0.9185, train_accuracy: 0.1903, test_accuracy: 0.1884
# Epoch 91, train_sat: 0.9178, test_sat: 0.9187, train_accuracy: 0.1898, test_accuracy: 0.1878
# Epoch 92, train_sat: 0.9180, test_sat: 0.9190, train_accuracy: 0.1892, test_accuracy: 0.1872
# Epoch 93, train_sat: 0.9183, test_sat: 0.9192, train_accuracy: 0.1886, test_accuracy: 0.1866
# Epoch 94, train_sat: 0.9185, test_sat: 0.9195, train_accuracy: 0.1880, test_accuracy: 0.1859
# Epoch 95, train_sat: 0.9188, test_sat: 0.9197, train_accuracy: 0.1873, test_accuracy: 0.1852
# Epoch 96, train_sat: 0.9191, test_sat: 0.9201, train_accuracy: 0.1865, test_accuracy: 0.1844
# Epoch 97, train_sat: 0.9194, test_sat: 0.9204, train_accuracy: 0.1857, test_accuracy: 0.1836
# Epoch 98, train_sat: 0.9197, test_sat: 0.9207, train_accuracy: 0.1849, test_accuracy: 0.1827
# Epoch 99, train_sat: 0.9201, test_sat: 0.9211, train_accuracy: 0.1840, test_accuracy: 0.1818
# Epoch 100, train_sat: 0.9205, test_sat: 0.9215, train_accuracy: 0.1830, test_accuracy: 0.1808
# Epoch 101, train_sat: 0.9209, test_sat: 0.9219, train_accuracy: 0.1820, test_accuracy: 0.1798
# Epoch 102, train_sat: 0.9213, test_sat: 0.9224, train_accuracy: 0.1810, test_accuracy: 0.1787
# Epoch 103, train_sat: 0.9218, test_sat: 0.9228, train_accuracy: 0.1799, test_accuracy: 0.1776
# Epoch 104, train_sat: 0.9223, test_sat: 0.9233, train_accuracy: 0.1788, test_accuracy: 0.1765
# Epoch 105, train_sat: 0.9228, test_sat: 0.9238, train_accuracy: 0.1776, test_accuracy: 0.1753
# Epoch 106, train_sat: 0.9233, test_sat: 0.9243, train_accuracy: 0.1764, test_accuracy: 0.1742
# Epoch 107, train_sat: 0.9238, test_sat: 0.9248, train_accuracy: 0.1753, test_accuracy: 0.1730
# Epoch 108, train_sat: 0.9243, test_sat: 0.9254, train_accuracy: 0.1741, test_accuracy: 0.1718
# Epoch 109, train_sat: 0.9248, test_sat: 0.9259, train_accuracy: 0.1729, test_accuracy: 0.1706
# Epoch 110, train_sat: 0.9253, test_sat: 0.9264, train_accuracy: 0.1718, test_accuracy: 0.1694
# Epoch 111, train_sat: 0.9258, test_sat: 0.9268, train_accuracy: 0.1707, test_accuracy: 0.1683
# Epoch 112, train_sat: 0.9263, test_sat: 0.9273, train_accuracy: 0.1696, test_accuracy: 0.1672
# Epoch 113, train_sat: 0.9267, test_sat: 0.9278, train_accuracy: 0.1686, test_accuracy: 0.1661
# Epoch 114, train_sat: 0.9271, test_sat: 0.9282, train_accuracy: 0.1676, test_accuracy: 0.1651
# Epoch 115, train_sat: 0.9276, test_sat: 0.9286, train_accuracy: 0.1666, test_accuracy: 0.1641
# Epoch 116, train_sat: 0.9280, test_sat: 0.9290, train_accuracy: 0.1657, test_accuracy: 0.1632
# Epoch 117, train_sat: 0.9283, test_sat: 0.9294, train_accuracy: 0.1648, test_accuracy: 0.1623
# Epoch 118, train_sat: 0.9287, test_sat: 0.9298, train_accuracy: 0.1640, test_accuracy: 0.1615
# Epoch 119, train_sat: 0.9291, test_sat: 0.9301, train_accuracy: 0.1632, test_accuracy: 0.1607
# Epoch 120, train_sat: 0.9294, test_sat: 0.9304, train_accuracy: 0.1625, test_accuracy: 0.1599
# Epoch 121, train_sat: 0.9297, test_sat: 0.9307, train_accuracy: 0.1617, test_accuracy: 0.1592
# Epoch 122, train_sat: 0.9300, test_sat: 0.9310, train_accuracy: 0.1610, test_accuracy: 0.1585
# Epoch 123, train_sat: 0.9303, test_sat: 0.9313, train_accuracy: 0.1604, test_accuracy: 0.1579
# Epoch 124, train_sat: 0.9306, test_sat: 0.9316, train_accuracy: 0.1598, test_accuracy: 0.1573
# Epoch 125, train_sat: 0.9309, test_sat: 0.9319, train_accuracy: 0.1591, test_accuracy: 0.1567
# Epoch 126, train_sat: 0.9311, test_sat: 0.9321, train_accuracy: 0.1586, test_accuracy: 0.1561
# Epoch 127, train_sat: 0.9314, test_sat: 0.9324, train_accuracy: 0.1580, test_accuracy: 0.1555
# Epoch 128, train_sat: 0.9316, test_sat: 0.9326, train_accuracy: 0.1574, test_accuracy: 0.1550
# Epoch 129, train_sat: 0.9319, test_sat: 0.9328, train_accuracy: 0.1569, test_accuracy: 0.1545
# Epoch 130, train_sat: 0.9321, test_sat: 0.9330, train_accuracy: 0.1564, test_accuracy: 0.1540
# Epoch 131, train_sat: 0.9323, test_sat: 0.9332, train_accuracy: 0.1559, test_accuracy: 0.1535
# Epoch 132, train_sat: 0.9325, test_sat: 0.9334, train_accuracy: 0.1554, test_accuracy: 0.1530
# Epoch 133, train_sat: 0.9327, test_sat: 0.9336, train_accuracy: 0.1550, test_accuracy: 0.1526
# Epoch 134, train_sat: 0.9329, test_sat: 0.9338, train_accuracy: 0.1545, test_accuracy: 0.1521
# Epoch 135, train_sat: 0.9331, test_sat: 0.9340, train_accuracy: 0.1541, test_accuracy: 0.1517
# Epoch 136, train_sat: 0.9333, test_sat: 0.9342, train_accuracy: 0.1537, test_accuracy: 0.1513
# Epoch 137, train_sat: 0.9335, test_sat: 0.9343, train_accuracy: 0.1533, test_accuracy: 0.1509
# Epoch 138, train_sat: 0.9336, test_sat: 0.9345, train_accuracy: 0.1529, test_accuracy: 0.1506
# Epoch 139, train_sat: 0.9338, test_sat: 0.9347, train_accuracy: 0.1525, test_accuracy: 0.1502
# Epoch 140, train_sat: 0.9339, test_sat: 0.9348, train_accuracy: 0.1522, test_accuracy: 0.1499
# Epoch 141, train_sat: 0.9341, test_sat: 0.9350, train_accuracy: 0.1518, test_accuracy: 0.1495
# Epoch 142, train_sat: 0.9342, test_sat: 0.9351, train_accuracy: 0.1515, test_accuracy: 0.1492
# Epoch 143, train_sat: 0.9344, test_sat: 0.9352, train_accuracy: 0.1512, test_accuracy: 0.1489
# Epoch 144, train_sat: 0.9345, test_sat: 0.9354, train_accuracy: 0.1509, test_accuracy: 0.1486
# Epoch 145, train_sat: 0.9346, test_sat: 0.9355, train_accuracy: 0.1506, test_accuracy: 0.1483
# Epoch 146, train_sat: 0.9348, test_sat: 0.9356, train_accuracy: 0.1503, test_accuracy: 0.1480
# Epoch 147, train_sat: 0.9349, test_sat: 0.9357, train_accuracy: 0.1500, test_accuracy: 0.1478
# Epoch 148, train_sat: 0.9350, test_sat: 0.9358, train_accuracy: 0.1498, test_accuracy: 0.1475
# Epoch 149, train_sat: 0.9351, test_sat: 0.9359, train_accuracy: 0.1495, test_accuracy: 0.1473
# Epoch 150, train_sat: 0.9352, test_sat: 0.9360, train_accuracy: 0.1493, test_accuracy: 0.1470
# Epoch 151, train_sat: 0.9353, test_sat: 0.9361, train_accuracy: 0.1491, test_accuracy: 0.1468
# Epoch 152, train_sat: 0.9354, test_sat: 0.9362, train_accuracy: 0.1488, test_accuracy: 0.1466
# Epoch 153, train_sat: 0.9355, test_sat: 0.9363, train_accuracy: 0.1486, test_accuracy: 0.1463
# Epoch 154, train_sat: 0.9356, test_sat: 0.9364, train_accuracy: 0.1484, test_accuracy: 0.1461
# Epoch 155, train_sat: 0.9357, test_sat: 0.9365, train_accuracy: 0.1482, test_accuracy: 0.1459
# Epoch 156, train_sat: 0.9358, test_sat: 0.9366, train_accuracy: 0.1480, test_accuracy: 0.1457
# Epoch 157, train_sat: 0.9359, test_sat: 0.9367, train_accuracy: 0.1478, test_accuracy: 0.1455
# Epoch 158, train_sat: 0.9360, test_sat: 0.9368, train_accuracy: 0.1476, test_accuracy: 0.1453
# Epoch 159, train_sat: 0.9360, test_sat: 0.9368, train_accuracy: 0.1474, test_accuracy: 0.1452
# Epoch 160, train_sat: 0.9361, test_sat: 0.9369, train_accuracy: 0.1472, test_accuracy: 0.1450
# Epoch 161, train_sat: 0.9362, test_sat: 0.9370, train_accuracy: 0.1470, test_accuracy: 0.1448
# Epoch 162, train_sat: 0.9363, test_sat: 0.9371, train_accuracy: 0.1469, test_accuracy: 0.1446
# Epoch 163, train_sat: 0.9364, test_sat: 0.9371, train_accuracy: 0.1467, test_accuracy: 0.1444
# Epoch 164, train_sat: 0.9364, test_sat: 0.9372, train_accuracy: 0.1465, test_accuracy: 0.1443
# Epoch 165, train_sat: 0.9365, test_sat: 0.9373, train_accuracy: 0.1464, test_accuracy: 0.1441
# Epoch 166, train_sat: 0.9366, test_sat: 0.9374, train_accuracy: 0.1462, test_accuracy: 0.1440
# Epoch 167, train_sat: 0.9366, test_sat: 0.9374, train_accuracy: 0.1461, test_accuracy: 0.1438
# Epoch 168, train_sat: 0.9367, test_sat: 0.9375, train_accuracy: 0.1459, test_accuracy: 0.1436
# Epoch 169, train_sat: 0.9368, test_sat: 0.9376, train_accuracy: 0.1457, test_accuracy: 0.1435
# Epoch 170, train_sat: 0.9368, test_sat: 0.9376, train_accuracy: 0.1456, test_accuracy: 0.1434
# Epoch 171, train_sat: 0.9369, test_sat: 0.9377, train_accuracy: 0.1455, test_accuracy: 0.1432
# Epoch 172, train_sat: 0.9370, test_sat: 0.9377, train_accuracy: 0.1453, test_accuracy: 0.1431
# Epoch 173, train_sat: 0.9370, test_sat: 0.9378, train_accuracy: 0.1452, test_accuracy: 0.1429
# Epoch 174, train_sat: 0.9371, test_sat: 0.9379, train_accuracy: 0.1450, test_accuracy: 0.1428
# Epoch 175, train_sat: 0.9372, test_sat: 0.9379, train_accuracy: 0.1449, test_accuracy: 0.1427
# Epoch 176, train_sat: 0.9372, test_sat: 0.9380, train_accuracy: 0.1448, test_accuracy: 0.1425
# Epoch 177, train_sat: 0.9373, test_sat: 0.9380, train_accuracy: 0.1446, test_accuracy: 0.1424
# Epoch 178, train_sat: 0.9373, test_sat: 0.9381, train_accuracy: 0.1445, test_accuracy: 0.1423
# Epoch 179, train_sat: 0.9374, test_sat: 0.9381, train_accuracy: 0.1444, test_accuracy: 0.1421
# Epoch 180, train_sat: 0.9374, test_sat: 0.9382, train_accuracy: 0.1443, test_accuracy: 0.1420
# Epoch 181, train_sat: 0.9375, test_sat: 0.9382, train_accuracy: 0.1442, test_accuracy: 0.1419
# Epoch 182, train_sat: 0.9375, test_sat: 0.9383, train_accuracy: 0.1440, test_accuracy: 0.1418
# Epoch 183, train_sat: 0.9376, test_sat: 0.9383, train_accuracy: 0.1439, test_accuracy: 0.1417
# Epoch 184, train_sat: 0.9376, test_sat: 0.9384, train_accuracy: 0.1438, test_accuracy: 0.1416
# Epoch 185, train_sat: 0.9377, test_sat: 0.9384, train_accuracy: 0.1437, test_accuracy: 0.1415
# Epoch 186, train_sat: 0.9377, test_sat: 0.9385, train_accuracy: 0.1436, test_accuracy: 0.1413
# Epoch 187, train_sat: 0.9378, test_sat: 0.9385, train_accuracy: 0.1435, test_accuracy: 0.1412
# Epoch 188, train_sat: 0.9378, test_sat: 0.9386, train_accuracy: 0.1434, test_accuracy: 0.1411
# Epoch 189, train_sat: 0.9379, test_sat: 0.9386, train_accuracy: 0.1433, test_accuracy: 0.1410
# Epoch 190, train_sat: 0.9379, test_sat: 0.9386, train_accuracy: 0.1432, test_accuracy: 0.1409
# Epoch 191, train_sat: 0.9379, test_sat: 0.9387, train_accuracy: 0.1431, test_accuracy: 0.1408
# Epoch 192, train_sat: 0.9380, test_sat: 0.9387, train_accuracy: 0.1430, test_accuracy: 0.1407
# Epoch 193, train_sat: 0.9380, test_sat: 0.9388, train_accuracy: 0.1429, test_accuracy: 0.1407
# Epoch 194, train_sat: 0.9381, test_sat: 0.9388, train_accuracy: 0.1428, test_accuracy: 0.1406
# Epoch 195, train_sat: 0.9381, test_sat: 0.9388, train_accuracy: 0.1428, test_accuracy: 0.1405
# Epoch 196, train_sat: 0.9381, test_sat: 0.9389, train_accuracy: 0.1427, test_accuracy: 0.1404
# Epoch 197, train_sat: 0.9382, test_sat: 0.9389, train_accuracy: 0.1426, test_accuracy: 0.1403
# Epoch 198, train_sat: 0.9382, test_sat: 0.9389, train_accuracy: 0.1425, test_accuracy: 0.1402
# Epoch 199, train_sat: 0.9382, test_sat: 0.9390, train_accuracy: 0.1424, test_accuracy: 0.1401
# Epoch 200, train_sat: 0.9383, test_sat: 0.9390, train_accuracy: 0.1423, test_accuracy: 0.1401
# Epoch 201, train_sat: 0.9383, test_sat: 0.9391, train_accuracy: 0.1423, test_accuracy: 0.1400
# Epoch 202, train_sat: 0.9383, test_sat: 0.9391, train_accuracy: 0.1422, test_accuracy: 0.1399
# Epoch 203, train_sat: 0.9384, test_sat: 0.9391, train_accuracy: 0.1421, test_accuracy: 0.1398
# Epoch 204, train_sat: 0.9384, test_sat: 0.9391, train_accuracy: 0.1420, test_accuracy: 0.1397
# Epoch 205, train_sat: 0.9384, test_sat: 0.9392, train_accuracy: 0.1420, test_accuracy: 0.1397
# Epoch 206, train_sat: 0.9385, test_sat: 0.9392, train_accuracy: 0.1419, test_accuracy: 0.1396
# Epoch 207, train_sat: 0.9385, test_sat: 0.9392, train_accuracy: 0.1418, test_accuracy: 0.1395
# Epoch 208, train_sat: 0.9385, test_sat: 0.9393, train_accuracy: 0.1418, test_accuracy: 0.1395
# Epoch 209, train_sat: 0.9386, test_sat: 0.9393, train_accuracy: 0.1417, test_accuracy: 0.1394
# Epoch 210, train_sat: 0.9386, test_sat: 0.9393, train_accuracy: 0.1416, test_accuracy: 0.1393
# Epoch 211, train_sat: 0.9386, test_sat: 0.9394, train_accuracy: 0.1416, test_accuracy: 0.1393
# Epoch 212, train_sat: 0.9386, test_sat: 0.9394, train_accuracy: 0.1415, test_accuracy: 0.1392
# Epoch 213, train_sat: 0.9387, test_sat: 0.9394, train_accuracy: 0.1415, test_accuracy: 0.1391
# Epoch 214, train_sat: 0.9387, test_sat: 0.9394, train_accuracy: 0.1414, test_accuracy: 0.1391
# Epoch 215, train_sat: 0.9387, test_sat: 0.9395, train_accuracy: 0.1413, test_accuracy: 0.1390
# Epoch 216, train_sat: 0.9387, test_sat: 0.9395, train_accuracy: 0.1413, test_accuracy: 0.1390
# Epoch 217, train_sat: 0.9388, test_sat: 0.9395, train_accuracy: 0.1412, test_accuracy: 0.1389
# Epoch 218, train_sat: 0.9388, test_sat: 0.9395, train_accuracy: 0.1412, test_accuracy: 0.1389
# Epoch 219, train_sat: 0.9388, test_sat: 0.9396, train_accuracy: 0.1411, test_accuracy: 0.1388
# Epoch 220, train_sat: 0.9388, test_sat: 0.9396, train_accuracy: 0.1411, test_accuracy: 0.1387
# Epoch 221, train_sat: 0.9388, test_sat: 0.9396, train_accuracy: 0.1410, test_accuracy: 0.1387
# Epoch 222, train_sat: 0.9389, test_sat: 0.9396, train_accuracy: 0.1410, test_accuracy: 0.1386
# Epoch 223, train_sat: 0.9389, test_sat: 0.9396, train_accuracy: 0.1409, test_accuracy: 0.1386
# Epoch 224, train_sat: 0.9389, test_sat: 0.9397, train_accuracy: 0.1409, test_accuracy: 0.1385
# Epoch 225, train_sat: 0.9389, test_sat: 0.9397, train_accuracy: 0.1408, test_accuracy: 0.1385
# Epoch 226, train_sat: 0.9390, test_sat: 0.9397, train_accuracy: 0.1408, test_accuracy: 0.1384
# Epoch 227, train_sat: 0.9390, test_sat: 0.9397, train_accuracy: 0.1407, test_accuracy: 0.1384
# Epoch 228, train_sat: 0.9390, test_sat: 0.9397, train_accuracy: 0.1407, test_accuracy: 0.1384
# Epoch 229, train_sat: 0.9390, test_sat: 0.9398, train_accuracy: 0.1407, test_accuracy: 0.1383
# Epoch 230, train_sat: 0.9390, test_sat: 0.9398, train_accuracy: 0.1406, test_accuracy: 0.1383
# Epoch 231, train_sat: 0.9390, test_sat: 0.9398, train_accuracy: 0.1406, test_accuracy: 0.1382
# Epoch 232, train_sat: 0.9391, test_sat: 0.9398, train_accuracy: 0.1405, test_accuracy: 0.1382
# Epoch 233, train_sat: 0.9391, test_sat: 0.9398, train_accuracy: 0.1405, test_accuracy: 0.1381
# Epoch 234, train_sat: 0.9391, test_sat: 0.9399, train_accuracy: 0.1405, test_accuracy: 0.1381
# Epoch 235, train_sat: 0.9391, test_sat: 0.9399, train_accuracy: 0.1404, test_accuracy: 0.1381
# Epoch 236, train_sat: 0.9391, test_sat: 0.9399, train_accuracy: 0.1404, test_accuracy: 0.1380
# Epoch 237, train_sat: 0.9391, test_sat: 0.9399, train_accuracy: 0.1404, test_accuracy: 0.1380
# Epoch 238, train_sat: 0.9392, test_sat: 0.9399, train_accuracy: 0.1403, test_accuracy: 0.1380
# Epoch 239, train_sat: 0.9392, test_sat: 0.9399, train_accuracy: 0.1403, test_accuracy: 0.1379
# Epoch 240, train_sat: 0.9392, test_sat: 0.9399, train_accuracy: 0.1402, test_accuracy: 0.1379
# Epoch 241, train_sat: 0.9392, test_sat: 0.9400, train_accuracy: 0.1402, test_accuracy: 0.1378
# Epoch 242, train_sat: 0.9392, test_sat: 0.9400, train_accuracy: 0.1402, test_accuracy: 0.1378
# Epoch 243, train_sat: 0.9392, test_sat: 0.9400, train_accuracy: 0.1401, test_accuracy: 0.1378
# Epoch 244, train_sat: 0.9393, test_sat: 0.9400, train_accuracy: 0.1401, test_accuracy: 0.1377
# Epoch 245, train_sat: 0.9393, test_sat: 0.9400, train_accuracy: 0.1401, test_accuracy: 0.1377
# Epoch 246, train_sat: 0.9393, test_sat: 0.9400, train_accuracy: 0.1401, test_accuracy: 0.1377
# Epoch 247, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 248, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 249, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 250, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 251, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 252, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 253, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 254, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 255, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 256, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 257, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 258, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 259, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 260, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 261, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 262, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 263, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 264, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 265, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 266, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 267, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 268, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 269, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 270, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 271, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 272, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 273, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 274, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 275, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 276, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 277, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 278, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 279, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 280, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 281, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 282, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 283, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 284, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 285, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 286, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 287, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 288, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 289, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 290, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 291, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 292, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 293, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 294, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 295, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 296, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 297, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 298, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan
# Epoch 299, train_sat: nan, test_sat: nan, train_accuracy: nan, test_accuracy: nan

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()
# Out:
# /var/folders/9m/k3vyv4317cz56g6f681k4jnm0000gn/T/ipykernel_82999/2816936712.py:12: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.savefig("LTN_regresie_2")
# /var/folders/9m/k3vyv4317cz56g6f681k4jnm0000gn/T/ipykernel_82999/2816936712.py:12: UserWarning: Attempted to set non-positive right xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.savefig("LTN_regresie_2")

# %%
tabel4_lucrare = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_tabel4_v4csv.csv", on_bad_lines='skip')
tabel4_lucrare.head(10)
# Out:
#    Pozitie  Severitate def  Severitate inc.     Mod 1     Mod 2     Mod 3  \
# 0    0.100        0.003346         0.000000  0.002393  0.001227  0.000540
# 1    0.150        0.003346         0.000000  0.001899  0.000254  0.000038
# 2    0.400        0.003346         0.000000  0.000644  0.001020  0.000683
# 3    0.550        0.003346         0.000000  0.000240  0.001535  0.000256
# 4    0.613        0.003346         0.000000  0.000141  0.001343  0.000991
# 5    0.133        0.003346         0.001673  0.002224  0.000466  0.000003
# 6    0.280        0.005124         0.001673  0.004237  0.002804  0.004348
# 7    0.410        0.003346         0.001673  0.002522  0.003063  0.002483
# 8    0.570        0.003346         0.001673  0.000218  0.001670  0.000507
# 9    0.962        0.001191         0.004333  0.000412  0.000412  0.000414
#
#       Mod 4     Mod 5     Mod 6     Mod 7     Mod 8
# 0  0.000099  0.000015  0.000075  0.000336  0.000652
# 1  0.000552  0.001173  0.001254  0.000798  0.000219
# 2  0.000299  0.001480  0.000037  0.001166  0.000771
# 3  0.001080  0.000632  0.000640  0.001072  0.000240
# 4  0.000146  0.001467  0.000171  0.000805  0.001136
# 5  0.000336  0.001015  0.001417  0.001310  0.000770
# 6  0.003654  0.002554  0.003922  0.004598  0.002963
# 7  0.002346  0.003381  0.001844  0.003377  0.002300
# 8  0.000837  0.001160  0.000208  0.001627  0.000020
# 9  0.000419  0.000429  0.000446  0.000472  0.000507

# %%
x = tabel4_lucrare.drop(['Pozitie','Severitate def', 'Severitate inc.', ], axis = 1)
y = tabel4_lucrare[['Pozitie']].values

# %%
batch_size= 8
test_tabel4 = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in test_tabel4:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,10)
ax.set_ylim(0,10)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Training Data')

# %%
df
# Out:
#    y_pred  y_true
# 0     NaN   0.100
# 1     NaN   0.150
# 2     NaN   0.400
# 3     NaN   0.550
# 4     NaN   0.613
# 5     NaN   0.133
# 6     NaN   0.280
# 7     NaN   0.410
# 8     NaN   0.570
# 9     NaN   0.962
