# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
#df.sample(5)
#df.shape
df = df.head(int(len(df)*(70/100)))
df.shape
# Out:
# (25601, 11)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
#df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (25601, 11)

# %%
x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

batch_size= 32
ds_train = tf.data.Dataset.from_tensor_slices((x[:21000],y[:21000])).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x[21000:],y[21000:])).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-05-17 18:16:29.283215: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-17 18:16:29.283307: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[10],output_shape=[1],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.78470
# 2022-05-17 18:16:29.968553: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-17 18:16:29.968605: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 50

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="regression_results.csv",
    track_metrics=1
)
# Out:
# 2022-05-17 18:16:30.157276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 18:16:37.065746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 18:16:37.228902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-17 18:16:37.761466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.9143, test_sat: 0.9412, train_accuracy: 0.2038, test_accuracy: 0.1349
# Epoch 1, train_sat: 0.9379, test_sat: 0.9405, train_accuracy: 0.1455, test_accuracy: 0.1369
# Epoch 2, train_sat: 0.9476, test_sat: 0.9528, train_accuracy: 0.1220, test_accuracy: 0.1056
# Epoch 3, train_sat: 0.9538, test_sat: 0.9588, train_accuracy: 0.1081, test_accuracy: 0.0945
# Epoch 4, train_sat: 0.9572, test_sat: 0.9354, train_accuracy: 0.0992, test_accuracy: 0.1461
# Epoch 5, train_sat: 0.9618, test_sat: 0.9646, train_accuracy: 0.0899, test_accuracy: 0.0809
# Epoch 6, train_sat: 0.9627, test_sat: 0.9599, train_accuracy: 0.0877, test_accuracy: 0.0861
# Epoch 7, train_sat: 0.9637, test_sat: 0.9596, train_accuracy: 0.0845, test_accuracy: 0.0873
# Epoch 8, train_sat: 0.9667, test_sat: 0.9817, train_accuracy: 0.0779, test_accuracy: 0.0397
# Epoch 9, train_sat: 0.9680, test_sat: 0.9639, train_accuracy: 0.0741, test_accuracy: 0.0771
# Epoch 10, train_sat: 0.9675, test_sat: 0.9584, train_accuracy: 0.0769, test_accuracy: 0.0946
# Epoch 11, train_sat: 0.9698, test_sat: 0.9848, train_accuracy: 0.0707, test_accuracy: 0.0336
# Epoch 12, train_sat: 0.9707, test_sat: 0.9672, train_accuracy: 0.0690, test_accuracy: 0.0738
# Epoch 13, train_sat: 0.9734, test_sat: 0.9618, train_accuracy: 0.0620, test_accuracy: 0.0878
# Epoch 14, train_sat: 0.9743, test_sat: 0.9789, train_accuracy: 0.0600, test_accuracy: 0.0444
# Epoch 15, train_sat: 0.9745, test_sat: 0.9487, train_accuracy: 0.0595, test_accuracy: 0.1164
# Epoch 16, train_sat: 0.9733, test_sat: 0.9852, train_accuracy: 0.0633, test_accuracy: 0.0323
# Epoch 17, train_sat: 0.9735, test_sat: 0.9694, train_accuracy: 0.0640, test_accuracy: 0.0667
# Epoch 18, train_sat: 0.9760, test_sat: 0.9764, train_accuracy: 0.0565, test_accuracy: 0.0527
# Epoch 19, train_sat: 0.9768, test_sat: 0.9650, train_accuracy: 0.0549, test_accuracy: 0.0768
# Epoch 20, train_sat: 0.9761, test_sat: 0.9607, train_accuracy: 0.0561, test_accuracy: 0.0859
# Epoch 21, train_sat: 0.9756, test_sat: 0.9766, train_accuracy: 0.0587, test_accuracy: 0.0517
# Epoch 22, train_sat: 0.9762, test_sat: 0.9712, train_accuracy: 0.0556, test_accuracy: 0.0616
# Epoch 23, train_sat: 0.9778, test_sat: 0.9745, train_accuracy: 0.0520, test_accuracy: 0.0544
# Epoch 24, train_sat: 0.9789, test_sat: 0.9808, train_accuracy: 0.0497, test_accuracy: 0.0413
# Epoch 25, train_sat: 0.9780, test_sat: 0.9706, train_accuracy: 0.0508, test_accuracy: 0.0649
# Epoch 26, train_sat: 0.9792, test_sat: 0.9817, train_accuracy: 0.0481, test_accuracy: 0.0389
# Epoch 27, train_sat: 0.9770, test_sat: 0.9770, train_accuracy: 0.0539, test_accuracy: 0.0513
# Epoch 28, train_sat: 0.9782, test_sat: 0.9832, train_accuracy: 0.0509, test_accuracy: 0.0372
# Epoch 29, train_sat: 0.9789, test_sat: 0.9881, train_accuracy: 0.0493, test_accuracy: 0.0248
# Epoch 30, train_sat: 0.9800, test_sat: 0.9589, train_accuracy: 0.0467, test_accuracy: 0.0913
# Epoch 31, train_sat: 0.9793, test_sat: 0.9762, train_accuracy: 0.0494, test_accuracy: 0.0508
# Epoch 32, train_sat: 0.9806, test_sat: 0.9845, train_accuracy: 0.0461, test_accuracy: 0.0322
# Epoch 33, train_sat: 0.9795, test_sat: 0.9810, train_accuracy: 0.0480, test_accuracy: 0.0409
# Epoch 34, train_sat: 0.9815, test_sat: 0.9748, train_accuracy: 0.0432, test_accuracy: 0.0555
# Epoch 35, train_sat: 0.9817, test_sat: 0.9710, train_accuracy: 0.0435, test_accuracy: 0.0636
# Epoch 36, train_sat: 0.9811, test_sat: 0.9761, train_accuracy: 0.0449, test_accuracy: 0.0515
# Epoch 37, train_sat: 0.9797, test_sat: 0.9799, train_accuracy: 0.0468, test_accuracy: 0.0429
# Epoch 38, train_sat: 0.9819, test_sat: 0.9836, train_accuracy: 0.0427, test_accuracy: 0.0355
# Epoch 39, train_sat: 0.9813, test_sat: 0.9740, train_accuracy: 0.0438, test_accuracy: 0.0550
# Epoch 40, train_sat: 0.9807, test_sat: 0.9920, train_accuracy: 0.0451, test_accuracy: 0.0167
# Epoch 41, train_sat: 0.9820, test_sat: 0.9724, train_accuracy: 0.0423, test_accuracy: 0.0613
# Epoch 42, train_sat: 0.9809, test_sat: 0.9726, train_accuracy: 0.0454, test_accuracy: 0.0617
# Epoch 43, train_sat: 0.9821, test_sat: 0.9886, train_accuracy: 0.0413, test_accuracy: 0.0246
# Epoch 44, train_sat: 0.9830, test_sat: 0.9619, train_accuracy: 0.0398, test_accuracy: 0.0856
# Epoch 45, train_sat: 0.9822, test_sat: 0.9792, train_accuracy: 0.0422, test_accuracy: 0.0448
# Epoch 46, train_sat: 0.9809, test_sat: 0.9822, train_accuracy: 0.0441, test_accuracy: 0.0378
# Epoch 47, train_sat: 0.9824, test_sat: 0.9821, train_accuracy: 0.0408, test_accuracy: 0.0391
# Epoch 48, train_sat: 0.9825, test_sat: 0.9790, train_accuracy: 0.0411, test_accuracy: 0.0433
# Epoch 49, train_sat: 0.9822, test_sat: 0.9727, train_accuracy: 0.0413, test_accuracy: 0.0590

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()

# %%
figure, axis = plt.subplots(figsize=(12,8))
x_ax = range(50)
axis.plot(x_ax, df['y_true'].tail(50), label="Pozitie", color='c')
axis.plot(x_ax, df['y_pred'].tail(50), label="Pozitie-pred", color='b')
axis.legend()


plt.savefig('test.pdf')  
plt.show()

# %%
df
# Out:
#         y_pred  y_true
# 0     0.712471   0.690
# 1     0.288088   0.264
# 2     0.156325   0.156
# 3     0.854079   0.788
# 4     0.889662   0.858
# ...        ...     ...
# 4596  0.851436   0.702
# 4597  0.536053   0.514
# 4598  0.482291   0.448
# 4599  0.057590   0.056
# 4600  0.732262   0.712
#
# [4601 rows x 2 columns]
