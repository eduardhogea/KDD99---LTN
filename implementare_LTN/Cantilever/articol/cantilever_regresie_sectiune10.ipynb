# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training_sectiune/tot.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
df_comp = df.sample(50) # un numar de valori random sa vedem acuratetea
#df.sample(5)
#df.shape
df = df.sample(int(len(df)*(10/100)))
print(df.shape)
# Out:
# (3657, 11)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler() 
# #df = scaler.fit_transform(df)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (3657, 11)

# %%
df_comp.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df_comp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_comp.dropna(inplace = True)
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df_comp.shape
# Out:
# Null values in dataset are 0
# (50, 11)

# %%
from sklearn.model_selection import train_test_split


x = df[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

x_comp = df_comp[['Severitate def', 'Severitate inc.','Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y_comp = df_comp[['Pozitie']]


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

#x_comp_train, x_comp_test, y_comp_train, y_comp_test = train_test_split(x_comp, y_comp, test_size=.2)

# %%
batch_size= 32
ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(batch_size)

#ds_comp_train = tf.data.Dataset.from_tensor_slices((x_comp_train,y_comp_train)).batch(batch_size)
ds_comp_test = tf.data.Dataset.from_tensor_slices((x_comp,y_comp)).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-05-24 15:41:33.815212: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-24 15:41:33.815302: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[10],output_shape=[1],hidden_layer_sizes=(100,100,50))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.77046
# 2022-05-24 15:41:34.491664: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-24 15:41:34.491718: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 160

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="regression_results.csv",
    track_metrics=1
)
# Out:
# 2022-05-24 15:41:34.673161: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-24 15:41:35.851797: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-24 15:41:36.016533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-05-24 15:41:36.166758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8925, test_sat: 0.8994, train_accuracy: 0.2596, test_accuracy: 0.2338
# Epoch 1, train_sat: 0.9064, test_sat: 0.8932, train_accuracy: 0.2183, test_accuracy: 0.2512
# Epoch 2, train_sat: 0.9067, test_sat: 0.9025, train_accuracy: 0.2194, test_accuracy: 0.2287
# Epoch 3, train_sat: 0.9159, test_sat: 0.9196, train_accuracy: 0.1954, test_accuracy: 0.1852
# Epoch 4, train_sat: 0.9163, test_sat: 0.9075, train_accuracy: 0.1942, test_accuracy: 0.2138
# Epoch 5, train_sat: 0.9196, test_sat: 0.9189, train_accuracy: 0.1863, test_accuracy: 0.1883
# Epoch 6, train_sat: 0.9250, test_sat: 0.9186, train_accuracy: 0.1743, test_accuracy: 0.1886
# Epoch 7, train_sat: 0.9321, test_sat: 0.9158, train_accuracy: 0.1560, test_accuracy: 0.1937
# Epoch 8, train_sat: 0.9334, test_sat: 0.9016, train_accuracy: 0.1562, test_accuracy: 0.2401
# Epoch 9, train_sat: 0.9366, test_sat: 0.9274, train_accuracy: 0.1481, test_accuracy: 0.1670
# Epoch 10, train_sat: 0.9370, test_sat: 0.9172, train_accuracy: 0.1454, test_accuracy: 0.1877
# Epoch 11, train_sat: 0.9423, test_sat: 0.9227, train_accuracy: 0.1342, test_accuracy: 0.1865
# Epoch 12, train_sat: 0.9451, test_sat: 0.9427, train_accuracy: 0.1268, test_accuracy: 0.1291
# Epoch 13, train_sat: 0.9427, test_sat: 0.9157, train_accuracy: 0.1335, test_accuracy: 0.1913
# Epoch 14, train_sat: 0.9434, test_sat: 0.9386, train_accuracy: 0.1313, test_accuracy: 0.1392
# Epoch 15, train_sat: 0.9485, test_sat: 0.9141, train_accuracy: 0.1207, test_accuracy: 0.1952
# Epoch 16, train_sat: 0.9435, test_sat: 0.9516, train_accuracy: 0.1298, test_accuracy: 0.1129
# Epoch 17, train_sat: 0.9515, test_sat: 0.9365, train_accuracy: 0.1111, test_accuracy: 0.1449
# Epoch 18, train_sat: 0.9518, test_sat: 0.9296, train_accuracy: 0.1112, test_accuracy: 0.1637
# Epoch 19, train_sat: 0.9472, test_sat: 0.9224, train_accuracy: 0.1238, test_accuracy: 0.1806
# Epoch 20, train_sat: 0.9482, test_sat: 0.9260, train_accuracy: 0.1207, test_accuracy: 0.1724
# Epoch 21, train_sat: 0.9536, test_sat: 0.9369, train_accuracy: 0.1058, test_accuracy: 0.1400
# Epoch 22, train_sat: 0.9583, test_sat: 0.9401, train_accuracy: 0.0947, test_accuracy: 0.1362
# Epoch 23, train_sat: 0.9469, test_sat: 0.9389, train_accuracy: 0.1220, test_accuracy: 0.1402
# Epoch 24, train_sat: 0.9555, test_sat: 0.9334, train_accuracy: 0.1027, test_accuracy: 0.1497
# Epoch 25, train_sat: 0.9539, test_sat: 0.9537, train_accuracy: 0.1052, test_accuracy: 0.1092
# Epoch 26, train_sat: 0.9551, test_sat: 0.9329, train_accuracy: 0.1057, test_accuracy: 0.1567
# Epoch 27, train_sat: 0.9594, test_sat: 0.9347, train_accuracy: 0.0930, test_accuracy: 0.1565
# Epoch 28, train_sat: 0.9592, test_sat: 0.9697, train_accuracy: 0.0969, test_accuracy: 0.0685
# Epoch 29, train_sat: 0.9583, test_sat: 0.9527, train_accuracy: 0.0975, test_accuracy: 0.1048
# Epoch 30, train_sat: 0.9656, test_sat: 0.9501, train_accuracy: 0.0779, test_accuracy: 0.1150
# Epoch 31, train_sat: 0.9505, test_sat: 0.9381, train_accuracy: 0.1147, test_accuracy: 0.1383
# Epoch 32, train_sat: 0.9533, test_sat: 0.9538, train_accuracy: 0.1057, test_accuracy: 0.1002
# Epoch 33, train_sat: 0.9547, test_sat: 0.9349, train_accuracy: 0.1064, test_accuracy: 0.1477
# Epoch 34, train_sat: 0.9577, test_sat: 0.9441, train_accuracy: 0.0959, test_accuracy: 0.1267
# Epoch 35, train_sat: 0.9635, test_sat: 0.9427, train_accuracy: 0.0826, test_accuracy: 0.1360
# Epoch 36, train_sat: 0.9575, test_sat: 0.9554, train_accuracy: 0.1005, test_accuracy: 0.0973
# Epoch 37, train_sat: 0.9633, test_sat: 0.9522, train_accuracy: 0.0842, test_accuracy: 0.1115
# Epoch 38, train_sat: 0.9606, test_sat: 0.9654, train_accuracy: 0.0910, test_accuracy: 0.0763
# Epoch 39, train_sat: 0.9660, test_sat: 0.9508, train_accuracy: 0.0787, test_accuracy: 0.1110
# Epoch 40, train_sat: 0.9693, test_sat: 0.9440, train_accuracy: 0.0713, test_accuracy: 0.1310
# Epoch 41, train_sat: 0.9635, test_sat: 0.9513, train_accuracy: 0.0856, test_accuracy: 0.1125
# Epoch 42, train_sat: 0.9653, test_sat: 0.9473, train_accuracy: 0.0808, test_accuracy: 0.1243
# Epoch 43, train_sat: 0.9635, test_sat: 0.9555, train_accuracy: 0.0838, test_accuracy: 0.0990
# Epoch 44, train_sat: 0.9620, test_sat: 0.9468, train_accuracy: 0.0873, test_accuracy: 0.1178
# Epoch 45, train_sat: 0.9628, test_sat: 0.9559, train_accuracy: 0.0877, test_accuracy: 0.1001
# Epoch 46, train_sat: 0.9627, test_sat: 0.9522, train_accuracy: 0.0859, test_accuracy: 0.1071
# Epoch 47, train_sat: 0.9640, test_sat: 0.9663, train_accuracy: 0.0830, test_accuracy: 0.0766
# Epoch 48, train_sat: 0.9632, test_sat: 0.9467, train_accuracy: 0.0834, test_accuracy: 0.1197
# Epoch 49, train_sat: 0.9650, test_sat: 0.9624, train_accuracy: 0.0782, test_accuracy: 0.0876
# Epoch 50, train_sat: 0.9662, test_sat: 0.9606, train_accuracy: 0.0764, test_accuracy: 0.0862
# Epoch 51, train_sat: 0.9675, test_sat: 0.9622, train_accuracy: 0.0748, test_accuracy: 0.0830
# Epoch 52, train_sat: 0.9642, test_sat: 0.9616, train_accuracy: 0.0827, test_accuracy: 0.0876
# Epoch 53, train_sat: 0.9678, test_sat: 0.9522, train_accuracy: 0.0777, test_accuracy: 0.1078
# Epoch 54, train_sat: 0.9676, test_sat: 0.9567, train_accuracy: 0.0748, test_accuracy: 0.0963
# Epoch 55, train_sat: 0.9695, test_sat: 0.9624, train_accuracy: 0.0712, test_accuracy: 0.0826
# Epoch 56, train_sat: 0.9649, test_sat: 0.9584, train_accuracy: 0.0827, test_accuracy: 0.0942
# Epoch 57, train_sat: 0.9712, test_sat: 0.9547, train_accuracy: 0.0656, test_accuracy: 0.1045
# Epoch 58, train_sat: 0.9642, test_sat: 0.9754, train_accuracy: 0.0857, test_accuracy: 0.0567
# Epoch 59, train_sat: 0.9670, test_sat: 0.9593, train_accuracy: 0.0780, test_accuracy: 0.0898
# Epoch 60, train_sat: 0.9675, test_sat: 0.9638, train_accuracy: 0.0762, test_accuracy: 0.0841
# Epoch 61, train_sat: 0.9672, test_sat: 0.9536, train_accuracy: 0.0780, test_accuracy: 0.1035
# Epoch 62, train_sat: 0.9678, test_sat: 0.9655, train_accuracy: 0.0741, test_accuracy: 0.0786
# Epoch 63, train_sat: 0.9642, test_sat: 0.9364, train_accuracy: 0.0836, test_accuracy: 0.1403
# Epoch 64, train_sat: 0.9674, test_sat: 0.9665, train_accuracy: 0.0747, test_accuracy: 0.0791
# Epoch 65, train_sat: 0.9705, test_sat: 0.9581, train_accuracy: 0.0675, test_accuracy: 0.0938
# Epoch 66, train_sat: 0.9724, test_sat: 0.9552, train_accuracy: 0.0626, test_accuracy: 0.0988
# Epoch 67, train_sat: 0.9644, test_sat: 0.9579, train_accuracy: 0.0823, test_accuracy: 0.0981
# Epoch 68, train_sat: 0.9693, test_sat: 0.9746, train_accuracy: 0.0728, test_accuracy: 0.0568
# Epoch 69, train_sat: 0.9729, test_sat: 0.9597, train_accuracy: 0.0625, test_accuracy: 0.0925
# Epoch 70, train_sat: 0.9693, test_sat: 0.9564, train_accuracy: 0.0702, test_accuracy: 0.1021
# Epoch 71, train_sat: 0.9707, test_sat: 0.9573, train_accuracy: 0.0667, test_accuracy: 0.0979
# Epoch 72, train_sat: 0.9699, test_sat: 0.9701, train_accuracy: 0.0707, test_accuracy: 0.0679
# Epoch 73, train_sat: 0.9695, test_sat: 0.9512, train_accuracy: 0.0709, test_accuracy: 0.1107
# Epoch 74, train_sat: 0.9714, test_sat: 0.9738, train_accuracy: 0.0673, test_accuracy: 0.0600
# Epoch 75, train_sat: 0.9678, test_sat: 0.9610, train_accuracy: 0.0722, test_accuracy: 0.0888
# Epoch 76, train_sat: 0.9707, test_sat: 0.9518, train_accuracy: 0.0675, test_accuracy: 0.1070
# Epoch 77, train_sat: 0.9690, test_sat: 0.9621, train_accuracy: 0.0698, test_accuracy: 0.0812
# Epoch 78, train_sat: 0.9706, test_sat: 0.9680, train_accuracy: 0.0698, test_accuracy: 0.0715
# Epoch 79, train_sat: 0.9684, test_sat: 0.9740, train_accuracy: 0.0742, test_accuracy: 0.0607
# Epoch 80, train_sat: 0.9707, test_sat: 0.9674, train_accuracy: 0.0680, test_accuracy: 0.0740
# Epoch 81, train_sat: 0.9720, test_sat: 0.9621, train_accuracy: 0.0656, test_accuracy: 0.0866
# Epoch 82, train_sat: 0.9699, test_sat: 0.9828, train_accuracy: 0.0708, test_accuracy: 0.0402
# Epoch 83, train_sat: 0.9703, test_sat: 0.9813, train_accuracy: 0.0723, test_accuracy: 0.0427
# Epoch 84, train_sat: 0.9679, test_sat: 0.9544, train_accuracy: 0.0776, test_accuracy: 0.1035
# Epoch 85, train_sat: 0.9674, test_sat: 0.9642, train_accuracy: 0.0765, test_accuracy: 0.0839
# Epoch 86, train_sat: 0.9690, test_sat: 0.9702, train_accuracy: 0.0722, test_accuracy: 0.0627
# Epoch 87, train_sat: 0.9704, test_sat: 0.9649, train_accuracy: 0.0680, test_accuracy: 0.0810
# Epoch 88, train_sat: 0.9713, test_sat: 0.9618, train_accuracy: 0.0708, test_accuracy: 0.0892
# Epoch 89, train_sat: 0.9668, test_sat: 0.9633, train_accuracy: 0.0809, test_accuracy: 0.0806
# Epoch 90, train_sat: 0.9721, test_sat: 0.9578, train_accuracy: 0.0655, test_accuracy: 0.0946
# Epoch 91, train_sat: 0.9693, test_sat: 0.9532, train_accuracy: 0.0731, test_accuracy: 0.1065
# Epoch 92, train_sat: 0.9712, test_sat: 0.9532, train_accuracy: 0.0654, test_accuracy: 0.1068
# Epoch 93, train_sat: 0.9744, test_sat: 0.9591, train_accuracy: 0.0593, test_accuracy: 0.0899
# Epoch 94, train_sat: 0.9729, test_sat: 0.9658, train_accuracy: 0.0631, test_accuracy: 0.0775
# Epoch 95, train_sat: 0.9713, test_sat: 0.9617, train_accuracy: 0.0650, test_accuracy: 0.0845
# Epoch 96, train_sat: 0.9672, test_sat: 0.9539, train_accuracy: 0.0780, test_accuracy: 0.1014
# Epoch 97, train_sat: 0.9689, test_sat: 0.9770, train_accuracy: 0.0721, test_accuracy: 0.0520
# Epoch 98, train_sat: 0.9740, test_sat: 0.9537, train_accuracy: 0.0616, test_accuracy: 0.1050
# Epoch 99, train_sat: 0.9701, test_sat: 0.9650, train_accuracy: 0.0687, test_accuracy: 0.0783
# Epoch 100, train_sat: 0.9707, test_sat: 0.9468, train_accuracy: 0.0683, test_accuracy: 0.1199
# Epoch 101, train_sat: 0.9672, test_sat: 0.9743, train_accuracy: 0.0743, test_accuracy: 0.0581
# Epoch 102, train_sat: 0.9665, test_sat: 0.9559, train_accuracy: 0.0771, test_accuracy: 0.0972
# Epoch 103, train_sat: 0.9744, test_sat: 0.9669, train_accuracy: 0.0572, test_accuracy: 0.0734
# Epoch 104, train_sat: 0.9706, test_sat: 0.9498, train_accuracy: 0.0736, test_accuracy: 0.1172
# Epoch 105, train_sat: 0.9663, test_sat: 0.9532, train_accuracy: 0.0786, test_accuracy: 0.1108
# Epoch 106, train_sat: 0.9707, test_sat: 0.9514, train_accuracy: 0.0697, test_accuracy: 0.1086
# Epoch 107, train_sat: 0.9693, test_sat: 0.9733, train_accuracy: 0.0712, test_accuracy: 0.0618
# Epoch 108, train_sat: 0.9725, test_sat: 0.9636, train_accuracy: 0.0640, test_accuracy: 0.0784
# Epoch 109, train_sat: 0.9683, test_sat: 0.9694, train_accuracy: 0.0756, test_accuracy: 0.0684
# Epoch 110, train_sat: 0.9715, test_sat: 0.9556, train_accuracy: 0.0650, test_accuracy: 0.0972
# Epoch 111, train_sat: 0.9760, test_sat: 0.9544, train_accuracy: 0.0544, test_accuracy: 0.1029
# Epoch 112, train_sat: 0.9743, test_sat: 0.9456, train_accuracy: 0.0576, test_accuracy: 0.1249
# Epoch 113, train_sat: 0.9707, test_sat: 0.9782, train_accuracy: 0.0679, test_accuracy: 0.0502
# Epoch 114, train_sat: 0.9752, test_sat: 0.9686, train_accuracy: 0.0579, test_accuracy: 0.0671
# Epoch 115, train_sat: 0.9746, test_sat: 0.9558, train_accuracy: 0.0574, test_accuracy: 0.0993
# Epoch 116, train_sat: 0.9760, test_sat: 0.9728, train_accuracy: 0.0540, test_accuracy: 0.0585
# Epoch 117, train_sat: 0.9731, test_sat: 0.9691, train_accuracy: 0.0629, test_accuracy: 0.0672
# Epoch 118, train_sat: 0.9738, test_sat: 0.9784, train_accuracy: 0.0617, test_accuracy: 0.0505
# Epoch 119, train_sat: 0.9750, test_sat: 0.9517, train_accuracy: 0.0586, test_accuracy: 0.1109
# Epoch 120, train_sat: 0.9704, test_sat: 0.9772, train_accuracy: 0.0671, test_accuracy: 0.0523
# Epoch 121, train_sat: 0.9749, test_sat: 0.9650, train_accuracy: 0.0594, test_accuracy: 0.0798
# Epoch 122, train_sat: 0.9753, test_sat: 0.9568, train_accuracy: 0.0564, test_accuracy: 0.0983
# Epoch 123, train_sat: 0.9733, test_sat: 0.9693, train_accuracy: 0.0624, test_accuracy: 0.0668
# Epoch 124, train_sat: 0.9670, test_sat: 0.9696, train_accuracy: 0.0792, test_accuracy: 0.0666
# Epoch 125, train_sat: 0.9727, test_sat: 0.9815, train_accuracy: 0.0646, test_accuracy: 0.0414
# Epoch 126, train_sat: 0.9770, test_sat: 0.9601, train_accuracy: 0.0519, test_accuracy: 0.0895
# Epoch 127, train_sat: 0.9709, test_sat: 0.9291, train_accuracy: 0.0678, test_accuracy: 0.1683
# Epoch 128, train_sat: 0.9701, test_sat: 0.9731, train_accuracy: 0.0682, test_accuracy: 0.0623
# Epoch 129, train_sat: 0.9741, test_sat: 0.9662, train_accuracy: 0.0596, test_accuracy: 0.0748
# Epoch 130, train_sat: 0.9777, test_sat: 0.9603, train_accuracy: 0.0508, test_accuracy: 0.0877
# Epoch 131, train_sat: 0.9716, test_sat: 0.9587, train_accuracy: 0.0680, test_accuracy: 0.0896
# Epoch 132, train_sat: 0.9782, test_sat: 0.9767, train_accuracy: 0.0489, test_accuracy: 0.0529
# Epoch 133, train_sat: 0.9751, test_sat: 0.9796, train_accuracy: 0.0597, test_accuracy: 0.0478
# Epoch 134, train_sat: 0.9784, test_sat: 0.9701, train_accuracy: 0.0511, test_accuracy: 0.0655
# Epoch 135, train_sat: 0.9801, test_sat: 0.9720, train_accuracy: 0.0463, test_accuracy: 0.0609
# Epoch 136, train_sat: 0.9731, test_sat: 0.9789, train_accuracy: 0.0620, test_accuracy: 0.0477
# Epoch 137, train_sat: 0.9787, test_sat: 0.9752, train_accuracy: 0.0476, test_accuracy: 0.0546
# Epoch 138, train_sat: 0.9773, test_sat: 0.9810, train_accuracy: 0.0525, test_accuracy: 0.0432
# Epoch 139, train_sat: 0.9775, test_sat: 0.9731, train_accuracy: 0.0529, test_accuracy: 0.0596
# Epoch 140, train_sat: 0.9692, test_sat: 0.9794, train_accuracy: 0.0711, test_accuracy: 0.0433
# Epoch 141, train_sat: 0.9735, test_sat: 0.9793, train_accuracy: 0.0607, test_accuracy: 0.0461
# Epoch 142, train_sat: 0.9806, test_sat: 0.9732, train_accuracy: 0.0463, test_accuracy: 0.0598
# Epoch 143, train_sat: 0.9749, test_sat: 0.9755, train_accuracy: 0.0586, test_accuracy: 0.0514
# Epoch 144, train_sat: 0.9768, test_sat: 0.9666, train_accuracy: 0.0528, test_accuracy: 0.0735
# Epoch 145, train_sat: 0.9790, test_sat: 0.9837, train_accuracy: 0.0488, test_accuracy: 0.0367
# Epoch 146, train_sat: 0.9744, test_sat: 0.9594, train_accuracy: 0.0626, test_accuracy: 0.0871
# Epoch 147, train_sat: 0.9762, test_sat: 0.9553, train_accuracy: 0.0621, test_accuracy: 0.1027
# Epoch 148, train_sat: 0.9765, test_sat: 0.9601, train_accuracy: 0.0529, test_accuracy: 0.0875
# Epoch 149, train_sat: 0.9754, test_sat: 0.9603, train_accuracy: 0.0580, test_accuracy: 0.0878
# Epoch 150, train_sat: 0.9774, test_sat: 0.9614, train_accuracy: 0.0512, test_accuracy: 0.0869
# Epoch 151, train_sat: 0.9759, test_sat: 0.9579, train_accuracy: 0.0576, test_accuracy: 0.0939
# Epoch 152, train_sat: 0.9708, test_sat: 0.9591, train_accuracy: 0.0667, test_accuracy: 0.0887
# Epoch 153, train_sat: 0.9769, test_sat: 0.9528, train_accuracy: 0.0545, test_accuracy: 0.1068
# Epoch 154, train_sat: 0.9783, test_sat: 0.9639, train_accuracy: 0.0484, test_accuracy: 0.0809
# Epoch 155, train_sat: 0.9771, test_sat: 0.9685, train_accuracy: 0.0534, test_accuracy: 0.0703
# Epoch 156, train_sat: 0.9765, test_sat: 0.9697, train_accuracy: 0.0552, test_accuracy: 0.0693
# Epoch 157, train_sat: 0.9784, test_sat: 0.9768, train_accuracy: 0.0531, test_accuracy: 0.0490
# Epoch 158, train_sat: 0.9737, test_sat: 0.9757, train_accuracy: 0.0641, test_accuracy: 0.0545
# Epoch 159, train_sat: 0.9744, test_sat: 0.9845, train_accuracy: 0.0597, test_accuracy: 0.0330

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()

# %%
figure, axis = plt.subplots(figsize=(12,8))
x_ax = range(50)
axis.plot(x_ax, df['y_true'].tail(50), label="Pozitie", color='c')
axis.plot(x_ax, df['y_pred'].tail(50), label="Pozitie-pred", color='b')
axis.legend()


plt.savefig('test.pdf')  
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
# data = {'y_pred':[],'y_true':[]}
# for x,y in ds_comp_train:
#     data['y_pred'].extend(f.model(x)[:,0].numpy())
#     data['y_true'].extend(y[:,0].numpy())
# df = pd.DataFrame(data,columns=['y_pred','y_true'])
# ax.set_xlim(0,80)
# ax.set_ylim(0,80)
# sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
#             scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
# ax.plot([0,100],[0,100],color="gray",linestyle="--")
# ax.set_xlabel("Actual y values")
# ax.set_ylabel("Fitted y values")
# ax.set_title("Training Data")

# ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_comp_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# figure, axis = plt.subplots(figsize=(12,8))
# x_ax = range(50)
# axis.plot(x_ax, data['y_true'], label="Pozitie", color='c')
# axis.plot(x_ax, data['y_pred'], label="Pozitie-pred", color='b')
# axis.legend()


# plt.savefig('test10.png')  
# plt.show()

# %%
figure, axis = plt.subplots(figsize=(12,8))
x_ax = range(50)
axis.plot(x_ax, data['y_true'], label="Position", color='c')
axis.plot(x_ax, data['y_pred'], label="Position-predicted", color='b')
axis.legend(fontsize=18)
plt.title("Predicted and actual position with 10% of data - 160 epochs", fontsize=30)

#plt.savefig('test10_.pdf')  
plt.savefig('test10_160epochs.png')  
plt.show()
