# %%
import logging; logging.basicConfig(level=logging.INFO)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import logictensornetworks as ltn
import pandas as pd

# %%
df = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/training.csv", on_bad_lines='skip', skiprows=1)
df = df.sample(frac=1) #shuffle
#df.sample(5)
#df.shape
df = df.head(int(len(df)*(70/100)))
df.shape
# Out:
# (25601, 11)

# %%
df.drop_duplicates(keep= 'first', inplace=True) #eliminarea dublurilor liniilor
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()
print('Null values in dataset are',len(df[df.isnull().any(1)]))
df.shape
# Out:
# Null values in dataset are 0
# (25601, 11)

# %%
x = df[['Mod 1', 'Mod 2','Mod 3','Mod 4','Mod 5','Mod 6','Mod 7','Mod 8']]
y = df[['Pozitie']]

batch_size= 64
ds_train = tf.data.Dataset.from_tensor_slices((x[:21000],y[:21000])).batch(batch_size)
ds_test = tf.data.Dataset.from_tensor_slices((x[21000:],y[21000:])).batch(batch_size)
# Out:
# Metal device set to: Apple M1
# 2022-04-30 13:23:00.468766: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-30 13:23:00.468879: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#df['Freq 1    f1 [Hz]'] = df['Freq 1    f1 [Hz]'].astype(float, errors = 'raise')
df.dtypes
# Out:
# Pozitie            float64
# Severitate def     float64
# Severitate inc.    float64
# Mod 1              float64
# Mod 2              float64
# Mod 3              float64
# Mod 4              float64
# Mod 5              float64
# Mod 6              float64
# Mod 7              float64
# Mod 8              float64
# dtype: object

# %%
f = ltn.Function.MLP(input_shapes=[8],output_shape=[1],hidden_layer_sizes=(16,16))

# %%
eq = ltn.Predicate.Lambda(
    #lambda args: tf.exp(-0.05*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))        
    lambda args: 1/(1+0.5*tf.sqrt(tf.reduce_sum(tf.square(args[0]-args[1]),axis=1)))
)

# %%
Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(p=2),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(p=2),semantics="exists")

# %%
@tf.function
def axioms(x_data, y_data):
    x = ltn.Variable("x", x_data)
    y = ltn.Variable("y", y_data)
    return Forall(ltn.diag(x,y), eq([f(x),y])).tensor

# %%
for x, y in ds_test:
    print("Initial sat level %.5f"%axioms(x,y))
    break
# Out:
# Initial sat level 0.79150
# 2022-04-30 13:23:01.183173: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-30 13:23:01.183225: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
metrics_dict = {
    'train_sat': tf.keras.metrics.Mean(name='train_sat'),
    'test_sat': tf.keras.metrics.Mean(name='test_sat'),
    'train_accuracy': tf.keras.metrics.RootMeanSquaredError(name="train_accuracy"),
    'test_accuracy': tf.keras.metrics.RootMeanSquaredError(name="test_accuracy")
}

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
@tf.function
def train_step(x, y):
    # sat and update
    with tf.GradientTape() as tape:
        sat = axioms(x, y)
        loss = 1.-sat
    gradients = tape.gradient(loss, f.trainable_variables)
    optimizer.apply_gradients(zip(gradients, f.trainable_variables))
    sat = axioms(x, y)
    metrics_dict['train_sat'](sat)
    # accuracy
    metrics_dict['train_accuracy'](y,f.model(x))
    
@tf.function
def test_step(x, y):
    # sat
    sat = axioms(x, y)
    metrics_dict['test_sat'](sat)
    # accuracy
    metrics_dict['test_accuracy'](y,f.model(x))

# %%
from collections import defaultdict

def train(
        epochs,
        metrics_dict, 
        ds_train, 
        ds_test, 
        train_step, 
        test_step,
        track_metrics=1,
        csv_path=None,
        scheduled_parameters=defaultdict(lambda : {})
    ):
    """
    Args:
        epochs: int, number of training epochs.
        metrics_dict: dict, {"metrics_label": tf.keras.metrics instance}.
        ds_train: iterable dataset, e.g. using tf.data.Dataset.
        ds_test: iterable dataset, e.g. using tf.data.Dataset.
        train_step: callable function. the arguments passed to the function
            are the itered elements of ds_train.
        test_step: callable function. the arguments passed to the function
            are the itered elements of ds_test.
        csv_path: (optional) path to create a csv file, to save the metrics.
        scheduled_parameters: (optional) a dictionary that returns kwargs for
            the train_step and test_step functions, for each epoch.
            Call using scheduled_parameters[epoch].
    """
    template = "Epoch {}"
    for metrics_label in metrics_dict.keys():
        template += ", %s: {:.4f}" % metrics_label
    if csv_path is not None:
        csv_file = open(csv_path,"w+")
        headers = ",".join(["Epoch"]+list(metrics_dict.keys()))
        csv_template = ",".join(["{}" for _ in range(len(metrics_dict)+1)])
        csv_file.write(headers+"\n")
    
    for epoch in range(epochs):
        for metrics in metrics_dict.values():
            metrics.reset_states()

        for batch_elements in ds_train:
            train_step(*batch_elements,**scheduled_parameters[epoch])
        for batch_elements in ds_test:
            test_step(*batch_elements,**scheduled_parameters[epoch])

        metrics_results = [metrics.result() for metrics in metrics_dict.values()]
        if epoch%track_metrics == 0:
            print(template.format(epoch,*metrics_results))
        if csv_path is not None:
            csv_file.write(csv_template.format(epoch,*metrics_results)+"\n")
            csv_file.flush()
    if csv_path is not None:
        csv_file.close()

# %%
EPOCHS = 200

modelul = train(
    EPOCHS,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    csv_path="regression_results_tabel4+11.csv",
    track_metrics=1
)
# Out:
# 2022-04-30 13:23:01.361473: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 13:23:04.071490: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 13:23:04.222807: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-04-30 13:23:04.471563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 0, train_sat: 0.8691, test_sat: 0.8808, train_accuracy: 0.3260, test_accuracy: 0.2810
# Epoch 1, train_sat: 0.8827, test_sat: 0.8863, train_accuracy: 0.2760, test_accuracy: 0.2661
# Epoch 2, train_sat: 0.8901, test_sat: 0.8952, train_accuracy: 0.2570, test_accuracy: 0.2446
# Epoch 3, train_sat: 0.8985, test_sat: 0.9014, train_accuracy: 0.2371, test_accuracy: 0.2299
# Epoch 4, train_sat: 0.9015, test_sat: 0.9026, train_accuracy: 0.2311, test_accuracy: 0.2276
# Epoch 5, train_sat: 0.9019, test_sat: 0.9028, train_accuracy: 0.2307, test_accuracy: 0.2273
# Epoch 6, train_sat: 0.9020, test_sat: 0.9029, train_accuracy: 0.2305, test_accuracy: 0.2270
# Epoch 7, train_sat: 0.9021, test_sat: 0.9030, train_accuracy: 0.2304, test_accuracy: 0.2269
# Epoch 8, train_sat: 0.9021, test_sat: 0.9030, train_accuracy: 0.2302, test_accuracy: 0.2267
# Epoch 9, train_sat: 0.9022, test_sat: 0.9031, train_accuracy: 0.2301, test_accuracy: 0.2265
# Epoch 10, train_sat: 0.9022, test_sat: 0.9032, train_accuracy: 0.2299, test_accuracy: 0.2264
# Epoch 11, train_sat: 0.9023, test_sat: 0.9032, train_accuracy: 0.2297, test_accuracy: 0.2262
# Epoch 12, train_sat: 0.9024, test_sat: 0.9033, train_accuracy: 0.2295, test_accuracy: 0.2260
# Epoch 13, train_sat: 0.9024, test_sat: 0.9034, train_accuracy: 0.2293, test_accuracy: 0.2258
# Epoch 14, train_sat: 0.9025, test_sat: 0.9035, train_accuracy: 0.2290, test_accuracy: 0.2256
# Epoch 15, train_sat: 0.9026, test_sat: 0.9036, train_accuracy: 0.2288, test_accuracy: 0.2253
# Epoch 16, train_sat: 0.9027, test_sat: 0.9037, train_accuracy: 0.2285, test_accuracy: 0.2250
# Epoch 17, train_sat: 0.9028, test_sat: 0.9038, train_accuracy: 0.2282, test_accuracy: 0.2247
# Epoch 18, train_sat: 0.9030, test_sat: 0.9039, train_accuracy: 0.2278, test_accuracy: 0.2243
# Epoch 19, train_sat: 0.9031, test_sat: 0.9041, train_accuracy: 0.2274, test_accuracy: 0.2239
# Epoch 20, train_sat: 0.9033, test_sat: 0.9042, train_accuracy: 0.2269, test_accuracy: 0.2234
# Epoch 21, train_sat: 0.9035, test_sat: 0.9045, train_accuracy: 0.2264, test_accuracy: 0.2229
# Epoch 22, train_sat: 0.9037, test_sat: 0.9047, train_accuracy: 0.2257, test_accuracy: 0.2222
# Epoch 23, train_sat: 0.9040, test_sat: 0.9050, train_accuracy: 0.2250, test_accuracy: 0.2215
# Epoch 24, train_sat: 0.9043, test_sat: 0.9053, train_accuracy: 0.2241, test_accuracy: 0.2206
# Epoch 25, train_sat: 0.9047, test_sat: 0.9057, train_accuracy: 0.2230, test_accuracy: 0.2195
# Epoch 26, train_sat: 0.9052, test_sat: 0.9062, train_accuracy: 0.2218, test_accuracy: 0.2183
# Epoch 27, train_sat: 0.9057, test_sat: 0.9068, train_accuracy: 0.2202, test_accuracy: 0.2168
# Epoch 28, train_sat: 0.9064, test_sat: 0.9075, train_accuracy: 0.2184, test_accuracy: 0.2150
# Epoch 29, train_sat: 0.9072, test_sat: 0.9083, train_accuracy: 0.2163, test_accuracy: 0.2129
# Epoch 30, train_sat: 0.9081, test_sat: 0.9093, train_accuracy: 0.2139, test_accuracy: 0.2106
# Epoch 31, train_sat: 0.9092, test_sat: 0.9103, train_accuracy: 0.2112, test_accuracy: 0.2081
# Epoch 32, train_sat: 0.9103, test_sat: 0.9115, train_accuracy: 0.2085, test_accuracy: 0.2056
# Epoch 33, train_sat: 0.9113, test_sat: 0.9126, train_accuracy: 0.2059, test_accuracy: 0.2032
# Epoch 34, train_sat: 0.9123, test_sat: 0.9136, train_accuracy: 0.2036, test_accuracy: 0.2011
# Epoch 35, train_sat: 0.9132, test_sat: 0.9145, train_accuracy: 0.2017, test_accuracy: 0.1992
# Epoch 36, train_sat: 0.9140, test_sat: 0.9152, train_accuracy: 0.2001, test_accuracy: 0.1976
# Epoch 37, train_sat: 0.9146, test_sat: 0.9159, train_accuracy: 0.1988, test_accuracy: 0.1962
# Epoch 38, train_sat: 0.9151, test_sat: 0.9165, train_accuracy: 0.1976, test_accuracy: 0.1949
# Epoch 39, train_sat: 0.9156, test_sat: 0.9170, train_accuracy: 0.1966, test_accuracy: 0.1938
# Epoch 40, train_sat: 0.9160, test_sat: 0.9174, train_accuracy: 0.1956, test_accuracy: 0.1927
# Epoch 41, train_sat: 0.9164, test_sat: 0.9178, train_accuracy: 0.1947, test_accuracy: 0.1916
# Epoch 42, train_sat: 0.9167, test_sat: 0.9182, train_accuracy: 0.1937, test_accuracy: 0.1906
# Epoch 43, train_sat: 0.9171, test_sat: 0.9186, train_accuracy: 0.1928, test_accuracy: 0.1896
# Epoch 44, train_sat: 0.9175, test_sat: 0.9190, train_accuracy: 0.1918, test_accuracy: 0.1886
# Epoch 45, train_sat: 0.9178, test_sat: 0.9193, train_accuracy: 0.1909, test_accuracy: 0.1875
# Epoch 46, train_sat: 0.9182, test_sat: 0.9197, train_accuracy: 0.1898, test_accuracy: 0.1865
# Epoch 47, train_sat: 0.9186, test_sat: 0.9201, train_accuracy: 0.1888, test_accuracy: 0.1853
# Epoch 48, train_sat: 0.9190, test_sat: 0.9206, train_accuracy: 0.1877, test_accuracy: 0.1842
# Epoch 49, train_sat: 0.9195, test_sat: 0.9210, train_accuracy: 0.1865, test_accuracy: 0.1829
# Epoch 50, train_sat: 0.9199, test_sat: 0.9215, train_accuracy: 0.1852, test_accuracy: 0.1816
# Epoch 51, train_sat: 0.9204, test_sat: 0.9220, train_accuracy: 0.1839, test_accuracy: 0.1803
# Epoch 52, train_sat: 0.9210, test_sat: 0.9226, train_accuracy: 0.1825, test_accuracy: 0.1788
# Epoch 53, train_sat: 0.9216, test_sat: 0.9232, train_accuracy: 0.1810, test_accuracy: 0.1772
# Epoch 54, train_sat: 0.9222, test_sat: 0.9239, train_accuracy: 0.1795, test_accuracy: 0.1756
# Epoch 55, train_sat: 0.9229, test_sat: 0.9246, train_accuracy: 0.1778, test_accuracy: 0.1739
# Epoch 56, train_sat: 0.9236, test_sat: 0.9253, train_accuracy: 0.1762, test_accuracy: 0.1722
# Epoch 57, train_sat: 0.9244, test_sat: 0.9260, train_accuracy: 0.1745, test_accuracy: 0.1706
# Epoch 58, train_sat: 0.9251, test_sat: 0.9267, train_accuracy: 0.1729, test_accuracy: 0.1689
# Epoch 59, train_sat: 0.9258, test_sat: 0.9273, train_accuracy: 0.1713, test_accuracy: 0.1674
# Epoch 60, train_sat: 0.9264, test_sat: 0.9280, train_accuracy: 0.1698, test_accuracy: 0.1659
# Epoch 61, train_sat: 0.9271, test_sat: 0.9286, train_accuracy: 0.1683, test_accuracy: 0.1645
# Epoch 62, train_sat: 0.9277, test_sat: 0.9291, train_accuracy: 0.1670, test_accuracy: 0.1633
# Epoch 63, train_sat: 0.9282, test_sat: 0.9297, train_accuracy: 0.1657, test_accuracy: 0.1621
# Epoch 64, train_sat: 0.9287, test_sat: 0.9301, train_accuracy: 0.1646, test_accuracy: 0.1610
# Epoch 65, train_sat: 0.9292, test_sat: 0.9306, train_accuracy: 0.1635, test_accuracy: 0.1600
# Epoch 66, train_sat: 0.9297, test_sat: 0.9310, train_accuracy: 0.1625, test_accuracy: 0.1590
# Epoch 67, train_sat: 0.9301, test_sat: 0.9314, train_accuracy: 0.1615, test_accuracy: 0.1582
# Epoch 68, train_sat: 0.9305, test_sat: 0.9318, train_accuracy: 0.1607, test_accuracy: 0.1573
# Epoch 69, train_sat: 0.9308, test_sat: 0.9322, train_accuracy: 0.1599, test_accuracy: 0.1566
# Epoch 70, train_sat: 0.9312, test_sat: 0.9325, train_accuracy: 0.1591, test_accuracy: 0.1559
# Epoch 71, train_sat: 0.9315, test_sat: 0.9328, train_accuracy: 0.1584, test_accuracy: 0.1552
# Epoch 72, train_sat: 0.9318, test_sat: 0.9330, train_accuracy: 0.1577, test_accuracy: 0.1545
# Epoch 73, train_sat: 0.9321, test_sat: 0.9333, train_accuracy: 0.1571, test_accuracy: 0.1539
# Epoch 74, train_sat: 0.9323, test_sat: 0.9335, train_accuracy: 0.1565, test_accuracy: 0.1534
# Epoch 75, train_sat: 0.9326, test_sat: 0.9338, train_accuracy: 0.1560, test_accuracy: 0.1529
# Epoch 76, train_sat: 0.9328, test_sat: 0.9340, train_accuracy: 0.1555, test_accuracy: 0.1524
# Epoch 77, train_sat: 0.9330, test_sat: 0.9342, train_accuracy: 0.1550, test_accuracy: 0.1519
# Epoch 78, train_sat: 0.9332, test_sat: 0.9344, train_accuracy: 0.1545, test_accuracy: 0.1514
# Epoch 79, train_sat: 0.9334, test_sat: 0.9345, train_accuracy: 0.1540, test_accuracy: 0.1510
# Epoch 80, train_sat: 0.9336, test_sat: 0.9347, train_accuracy: 0.1536, test_accuracy: 0.1505
# Epoch 81, train_sat: 0.9337, test_sat: 0.9349, train_accuracy: 0.1532, test_accuracy: 0.1502
# Epoch 82, train_sat: 0.9339, test_sat: 0.9350, train_accuracy: 0.1528, test_accuracy: 0.1498
# Epoch 83, train_sat: 0.9341, test_sat: 0.9352, train_accuracy: 0.1525, test_accuracy: 0.1494
# Epoch 84, train_sat: 0.9342, test_sat: 0.9353, train_accuracy: 0.1521, test_accuracy: 0.1491
# Epoch 85, train_sat: 0.9343, test_sat: 0.9355, train_accuracy: 0.1518, test_accuracy: 0.1488
# Epoch 86, train_sat: 0.9345, test_sat: 0.9356, train_accuracy: 0.1515, test_accuracy: 0.1485
# Epoch 87, train_sat: 0.9346, test_sat: 0.9357, train_accuracy: 0.1512, test_accuracy: 0.1482
# Epoch 88, train_sat: 0.9347, test_sat: 0.9358, train_accuracy: 0.1509, test_accuracy: 0.1479
# Epoch 89, train_sat: 0.9348, test_sat: 0.9359, train_accuracy: 0.1507, test_accuracy: 0.1477
# Epoch 90, train_sat: 0.9350, test_sat: 0.9360, train_accuracy: 0.1504, test_accuracy: 0.1475
# Epoch 91, train_sat: 0.9351, test_sat: 0.9361, train_accuracy: 0.1502, test_accuracy: 0.1472
# Epoch 92, train_sat: 0.9352, test_sat: 0.9362, train_accuracy: 0.1499, test_accuracy: 0.1470
# Epoch 93, train_sat: 0.9353, test_sat: 0.9363, train_accuracy: 0.1497, test_accuracy: 0.1468
# Epoch 94, train_sat: 0.9354, test_sat: 0.9364, train_accuracy: 0.1495, test_accuracy: 0.1467
# Epoch 95, train_sat: 0.9354, test_sat: 0.9365, train_accuracy: 0.1493, test_accuracy: 0.1465
# Epoch 96, train_sat: 0.9355, test_sat: 0.9365, train_accuracy: 0.1492, test_accuracy: 0.1463
# Epoch 97, train_sat: 0.9356, test_sat: 0.9366, train_accuracy: 0.1490, test_accuracy: 0.1462
# Epoch 98, train_sat: 0.9357, test_sat: 0.9367, train_accuracy: 0.1488, test_accuracy: 0.1460
# Epoch 99, train_sat: 0.9358, test_sat: 0.9368, train_accuracy: 0.1487, test_accuracy: 0.1459
# Epoch 100, train_sat: 0.9358, test_sat: 0.9368, train_accuracy: 0.1485, test_accuracy: 0.1458
# Epoch 101, train_sat: 0.9359, test_sat: 0.9369, train_accuracy: 0.1484, test_accuracy: 0.1456
# Epoch 102, train_sat: 0.9360, test_sat: 0.9369, train_accuracy: 0.1482, test_accuracy: 0.1455
# Epoch 103, train_sat: 0.9360, test_sat: 0.9370, train_accuracy: 0.1481, test_accuracy: 0.1454
# Epoch 104, train_sat: 0.9361, test_sat: 0.9370, train_accuracy: 0.1480, test_accuracy: 0.1453
# Epoch 105, train_sat: 0.9361, test_sat: 0.9371, train_accuracy: 0.1479, test_accuracy: 0.1452
# Epoch 106, train_sat: 0.9362, test_sat: 0.9371, train_accuracy: 0.1477, test_accuracy: 0.1451
# Epoch 107, train_sat: 0.9362, test_sat: 0.9372, train_accuracy: 0.1476, test_accuracy: 0.1450
# Epoch 108, train_sat: 0.9363, test_sat: 0.9372, train_accuracy: 0.1475, test_accuracy: 0.1449
# Epoch 109, train_sat: 0.9363, test_sat: 0.9373, train_accuracy: 0.1474, test_accuracy: 0.1448
# Epoch 110, train_sat: 0.9364, test_sat: 0.9373, train_accuracy: 0.1473, test_accuracy: 0.1447
# Epoch 111, train_sat: 0.9364, test_sat: 0.9374, train_accuracy: 0.1472, test_accuracy: 0.1446
# Epoch 112, train_sat: 0.9365, test_sat: 0.9374, train_accuracy: 0.1471, test_accuracy: 0.1445
# Epoch 113, train_sat: 0.9365, test_sat: 0.9375, train_accuracy: 0.1470, test_accuracy: 0.1444
# Epoch 114, train_sat: 0.9366, test_sat: 0.9375, train_accuracy: 0.1468, test_accuracy: 0.1443
# Epoch 115, train_sat: 0.9366, test_sat: 0.9376, train_accuracy: 0.1467, test_accuracy: 0.1442
# Epoch 116, train_sat: 0.9367, test_sat: 0.9376, train_accuracy: 0.1466, test_accuracy: 0.1441
# Epoch 117, train_sat: 0.9368, test_sat: 0.9377, train_accuracy: 0.1465, test_accuracy: 0.1440
# Epoch 118, train_sat: 0.9368, test_sat: 0.9377, train_accuracy: 0.1464, test_accuracy: 0.1438
# Epoch 119, train_sat: 0.9369, test_sat: 0.9378, train_accuracy: 0.1462, test_accuracy: 0.1437
# Epoch 120, train_sat: 0.9369, test_sat: 0.9378, train_accuracy: 0.1461, test_accuracy: 0.1436
# Epoch 121, train_sat: 0.9370, test_sat: 0.9379, train_accuracy: 0.1460, test_accuracy: 0.1435
# Epoch 122, train_sat: 0.9370, test_sat: 0.9379, train_accuracy: 0.1458, test_accuracy: 0.1433
# Epoch 123, train_sat: 0.9371, test_sat: 0.9380, train_accuracy: 0.1457, test_accuracy: 0.1432
# Epoch 124, train_sat: 0.9372, test_sat: 0.9381, train_accuracy: 0.1456, test_accuracy: 0.1431
# Epoch 125, train_sat: 0.9372, test_sat: 0.9381, train_accuracy: 0.1454, test_accuracy: 0.1429
# Epoch 126, train_sat: 0.9373, test_sat: 0.9382, train_accuracy: 0.1453, test_accuracy: 0.1428
# Epoch 127, train_sat: 0.9374, test_sat: 0.9383, train_accuracy: 0.1451, test_accuracy: 0.1427
# Epoch 128, train_sat: 0.9374, test_sat: 0.9383, train_accuracy: 0.1450, test_accuracy: 0.1425
# Epoch 129, train_sat: 0.9375, test_sat: 0.9384, train_accuracy: 0.1448, test_accuracy: 0.1424
# Epoch 130, train_sat: 0.9376, test_sat: 0.9385, train_accuracy: 0.1447, test_accuracy: 0.1422
# Epoch 131, train_sat: 0.9376, test_sat: 0.9385, train_accuracy: 0.1445, test_accuracy: 0.1421
# Epoch 132, train_sat: 0.9377, test_sat: 0.9386, train_accuracy: 0.1444, test_accuracy: 0.1419
# Epoch 133, train_sat: 0.9378, test_sat: 0.9387, train_accuracy: 0.1442, test_accuracy: 0.1418
# Epoch 134, train_sat: 0.9378, test_sat: 0.9387, train_accuracy: 0.1441, test_accuracy: 0.1416
# Epoch 135, train_sat: 0.9379, test_sat: 0.9388, train_accuracy: 0.1439, test_accuracy: 0.1415
# Epoch 136, train_sat: 0.9380, test_sat: 0.9389, train_accuracy: 0.1438, test_accuracy: 0.1413
# Epoch 137, train_sat: 0.9380, test_sat: 0.9389, train_accuracy: 0.1436, test_accuracy: 0.1412
# Epoch 138, train_sat: 0.9381, test_sat: 0.9390, train_accuracy: 0.1435, test_accuracy: 0.1410
# Epoch 139, train_sat: 0.9382, test_sat: 0.9391, train_accuracy: 0.1433, test_accuracy: 0.1409
# Epoch 140, train_sat: 0.9382, test_sat: 0.9391, train_accuracy: 0.1432, test_accuracy: 0.1407
# Epoch 141, train_sat: 0.9383, test_sat: 0.9392, train_accuracy: 0.1430, test_accuracy: 0.1406
# Epoch 142, train_sat: 0.9383, test_sat: 0.9393, train_accuracy: 0.1429, test_accuracy: 0.1404
# Epoch 143, train_sat: 0.9384, test_sat: 0.9393, train_accuracy: 0.1427, test_accuracy: 0.1403
# Epoch 144, train_sat: 0.9385, test_sat: 0.9394, train_accuracy: 0.1426, test_accuracy: 0.1401
# Epoch 145, train_sat: 0.9385, test_sat: 0.9395, train_accuracy: 0.1425, test_accuracy: 0.1400
# Epoch 146, train_sat: 0.9386, test_sat: 0.9395, train_accuracy: 0.1423, test_accuracy: 0.1398
# Epoch 147, train_sat: 0.9387, test_sat: 0.9396, train_accuracy: 0.1422, test_accuracy: 0.1397
# Epoch 148, train_sat: 0.9387, test_sat: 0.9397, train_accuracy: 0.1420, test_accuracy: 0.1396
# Epoch 149, train_sat: 0.9388, test_sat: 0.9397, train_accuracy: 0.1419, test_accuracy: 0.1394
# Epoch 150, train_sat: 0.9388, test_sat: 0.9398, train_accuracy: 0.1418, test_accuracy: 0.1393
# Epoch 151, train_sat: 0.9389, test_sat: 0.9398, train_accuracy: 0.1416, test_accuracy: 0.1392
# Epoch 152, train_sat: 0.9389, test_sat: 0.9399, train_accuracy: 0.1415, test_accuracy: 0.1390
# Epoch 153, train_sat: 0.9390, test_sat: 0.9399, train_accuracy: 0.1414, test_accuracy: 0.1389
# Epoch 154, train_sat: 0.9390, test_sat: 0.9400, train_accuracy: 0.1413, test_accuracy: 0.1388
# Epoch 155, train_sat: 0.9391, test_sat: 0.9401, train_accuracy: 0.1411, test_accuracy: 0.1386
# Epoch 156, train_sat: 0.9391, test_sat: 0.9401, train_accuracy: 0.1410, test_accuracy: 0.1385
# Epoch 157, train_sat: 0.9392, test_sat: 0.9402, train_accuracy: 0.1409, test_accuracy: 0.1384
# Epoch 158, train_sat: 0.9393, test_sat: 0.9402, train_accuracy: 0.1408, test_accuracy: 0.1383
# Epoch 159, train_sat: 0.9393, test_sat: 0.9403, train_accuracy: 0.1407, test_accuracy: 0.1381
# Epoch 160, train_sat: 0.9393, test_sat: 0.9403, train_accuracy: 0.1406, test_accuracy: 0.1380
# Epoch 161, train_sat: 0.9394, test_sat: 0.9404, train_accuracy: 0.1405, test_accuracy: 0.1379
# Epoch 162, train_sat: 0.9394, test_sat: 0.9404, train_accuracy: 0.1404, test_accuracy: 0.1378
# Epoch 163, train_sat: 0.9395, test_sat: 0.9405, train_accuracy: 0.1403, test_accuracy: 0.1377
# Epoch 164, train_sat: 0.9395, test_sat: 0.9405, train_accuracy: 0.1402, test_accuracy: 0.1376
# Epoch 165, train_sat: 0.9396, test_sat: 0.9406, train_accuracy: 0.1401, test_accuracy: 0.1375
# Epoch 166, train_sat: 0.9396, test_sat: 0.9406, train_accuracy: 0.1400, test_accuracy: 0.1374
# Epoch 167, train_sat: 0.9397, test_sat: 0.9407, train_accuracy: 0.1399, test_accuracy: 0.1373
# Epoch 168, train_sat: 0.9397, test_sat: 0.9407, train_accuracy: 0.1398, test_accuracy: 0.1372
# Epoch 169, train_sat: 0.9397, test_sat: 0.9407, train_accuracy: 0.1397, test_accuracy: 0.1371
# Epoch 170, train_sat: 0.9398, test_sat: 0.9408, train_accuracy: 0.1396, test_accuracy: 0.1370
# Epoch 171, train_sat: 0.9398, test_sat: 0.9408, train_accuracy: 0.1395, test_accuracy: 0.1369
# Epoch 172, train_sat: 0.9399, test_sat: 0.9409, train_accuracy: 0.1394, test_accuracy: 0.1368
# Epoch 173, train_sat: 0.9399, test_sat: 0.9409, train_accuracy: 0.1393, test_accuracy: 0.1367
# Epoch 174, train_sat: 0.9399, test_sat: 0.9409, train_accuracy: 0.1392, test_accuracy: 0.1366
# Epoch 175, train_sat: 0.9400, test_sat: 0.9410, train_accuracy: 0.1392, test_accuracy: 0.1366
# Epoch 176, train_sat: 0.9400, test_sat: 0.9410, train_accuracy: 0.1391, test_accuracy: 0.1365
# Epoch 177, train_sat: 0.9400, test_sat: 0.9411, train_accuracy: 0.1390, test_accuracy: 0.1364
# Epoch 178, train_sat: 0.9401, test_sat: 0.9411, train_accuracy: 0.1389, test_accuracy: 0.1363
# Epoch 179, train_sat: 0.9401, test_sat: 0.9411, train_accuracy: 0.1389, test_accuracy: 0.1362
# Epoch 180, train_sat: 0.9401, test_sat: 0.9412, train_accuracy: 0.1388, test_accuracy: 0.1362
# Epoch 181, train_sat: 0.9402, test_sat: 0.9412, train_accuracy: 0.1387, test_accuracy: 0.1361
# Epoch 182, train_sat: 0.9402, test_sat: 0.9412, train_accuracy: 0.1386, test_accuracy: 0.1360
# Epoch 183, train_sat: 0.9402, test_sat: 0.9413, train_accuracy: 0.1386, test_accuracy: 0.1359
# Epoch 184, train_sat: 0.9403, test_sat: 0.9413, train_accuracy: 0.1385, test_accuracy: 0.1359
# Epoch 185, train_sat: 0.9403, test_sat: 0.9413, train_accuracy: 0.1384, test_accuracy: 0.1358
# Epoch 186, train_sat: 0.9403, test_sat: 0.9414, train_accuracy: 0.1384, test_accuracy: 0.1357
# Epoch 187, train_sat: 0.9404, test_sat: 0.9414, train_accuracy: 0.1383, test_accuracy: 0.1357
# Epoch 188, train_sat: 0.9404, test_sat: 0.9414, train_accuracy: 0.1382, test_accuracy: 0.1356
# Epoch 189, train_sat: 0.9404, test_sat: 0.9414, train_accuracy: 0.1382, test_accuracy: 0.1355
# Epoch 190, train_sat: 0.9404, test_sat: 0.9415, train_accuracy: 0.1381, test_accuracy: 0.1355
# Epoch 191, train_sat: 0.9405, test_sat: 0.9415, train_accuracy: 0.1381, test_accuracy: 0.1354
# Epoch 192, train_sat: 0.9405, test_sat: 0.9415, train_accuracy: 0.1380, test_accuracy: 0.1353
# Epoch 193, train_sat: 0.9405, test_sat: 0.9416, train_accuracy: 0.1379, test_accuracy: 0.1353
# Epoch 194, train_sat: 0.9405, test_sat: 0.9416, train_accuracy: 0.1379, test_accuracy: 0.1352
# Epoch 195, train_sat: 0.9406, test_sat: 0.9416, train_accuracy: 0.1378, test_accuracy: 0.1351
# Epoch 196, train_sat: 0.9406, test_sat: 0.9416, train_accuracy: 0.1378, test_accuracy: 0.1351
# Epoch 197, train_sat: 0.9406, test_sat: 0.9417, train_accuracy: 0.1377, test_accuracy: 0.1350
# Epoch 198, train_sat: 0.9406, test_sat: 0.9417, train_accuracy: 0.1377, test_accuracy: 0.1350
# Epoch 199, train_sat: 0.9407, test_sat: 0.9417, train_accuracy: 0.1376, test_accuracy: 0.1349

# %%
import seaborn as sns
sns.set(font_scale=1.2)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_train:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Training Data")

ax = axs[1]
data = {'y_pred':[],'y_true':[]}
for x,y in ds_test:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
ax.set_ylim(0,80)
ax.set_xlim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Test Data")
plt.tight_layout()
plt.savefig("LTN_regresie_1.pdf")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['y_true'], df['y_pred'], c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(df['y_pred']), max(df['y_true']))
p2 = min(min(df['y_pred']), min(df['y_true']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.savefig("LTN_regresie_2")
plt.show()

# %%
tabel4_lucrare = pd.read_csv("/Users/eduard.hogea/Documents/Facultate/Internship/explorare/KNN99---LTN/datesets/Cantilever/date_tabel4_v2.csv", on_bad_lines='skip')
tabel4_lucrare.head(10)
# Out:
#    Pozitie  Severitate def  Severitate inc.     Mod 1     Mod 2     Mod 3  \
# 0    0.100          0.0010         0.000000  0.002393  0.001227  0.000540
# 1    0.150          0.0010         0.000000  0.001899  0.000254  0.000038
# 2    0.400          0.0010         0.000000  0.000644  0.001020  0.000683
# 3    0.550          0.0010         0.000000  0.000240  0.001535  0.000256
# 4    0.613          0.0010         0.000000  0.000141  0.001343  0.000991
# 5    0.133          0.0010         0.001673  0.002224  0.000466  0.000003
# 6    0.280          0.0012         0.001673  0.004237  0.002804  0.004348
# 7    0.410          0.0010         0.001673  0.002522  0.003063  0.002483
# 8    0.570          0.0010         0.001673  0.000218  0.001670  0.000507
# 9    0.962          0.0006         0.000433  0.000412  0.000412  0.000414
#
#       Mod 4     Mod 5     Mod 6     Mod 7     Mod 8
# 0  0.000099  0.000015  0.000075  0.000336  0.000652
# 1  0.000552  0.001173  0.001254  0.000798  0.000219
# 2  0.000299  0.001480  0.000037  0.001166  0.000771
# 3  0.001080  0.000632  0.000640  0.001072  0.000240
# 4  0.000146  0.001467  0.000171  0.000805  0.001136
# 5  0.000336  0.001015  0.001417  0.001310  0.000770
# 6  0.003654  0.002554  0.003922  0.004598  0.002963
# 7  0.002346  0.003381  0.001844  0.003377  0.002300
# 8  0.000837  0.001160  0.000208  0.001627  0.000020
# 9  0.000419  0.000429  0.000446  0.000472  0.000507

# %%
x = tabel4_lucrare.drop(['Pozitie','Severitate def', 'Severitate inc.'], axis = 1)
y = tabel4_lucrare[['Pozitie']].values

# %%
batch_size= 16
test_tabel4 = tf.data.Dataset.from_tensor_slices((x,y)).batch(batch_size)

# %%
data = {'y_pred':[],'y_true':[]}
for x,y in test_tabel4:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax = axs[0]
data = {'y_pred':[],'y_true':[]}
for x,y in test_tabel4:
    data['y_pred'].extend(f.model(x)[:,0].numpy())
    data['y_true'].extend(y[:,0].numpy())
df = pd.DataFrame(data,columns=['y_pred','y_true'])
df = df.abs()
ax.set_xlim(0,80)
ax.set_ylim(0,80)
sns.regplot("y_true","y_pred",data=df,ax=ax,truncate=False,
            scatter_kws={'alpha':0.5},line_kws={'color':'r','alpha':0.3,'linestyle':'--','linewidth':2})
ax.plot([0,100],[0,100],color="gray",linestyle="--")
ax.set_xlabel("Actual y values")
ax.set_ylabel("Fitted y values")
ax.set_title("Tabel 4 Data")
# Out:
# /Users/eduard.hogea/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Tabel 4 Data')

# %%
df
# Out:
#      y_pred  y_true
# 0  0.104070   0.100
# 1  0.180013   0.150
# 2  0.537211   0.400
# 3  0.644460   0.550
# 4  0.720134   0.613
# 5  0.162985   0.133
# 6  0.336844   0.280
# 7  0.414540   0.410
# 8  0.656280   0.570
# 9  0.601969   0.962

# %%
figure, axis = plt.subplots(figsize=(12,8))
x_ax = range(len(x))
axis.plot(x_ax, df['y_true'], label="Pozitie", color='c')
axis.plot(x_ax, df['y_pred'], label="Pozitie-pred", color='b')
axis.legend()


plt.savefig('tabel4_LTN.pdf')  
plt.show()
